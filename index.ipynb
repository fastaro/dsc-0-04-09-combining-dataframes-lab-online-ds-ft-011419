# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, we'll gain practice combining DataFrames through concatenation.  We'll also learn to read in tables from a database and store them in separate tables, as well as how to execute various types of joins to selectively combine the information stored in the tables!
#
#
# ## Objectives:
# You will be able to:
# * Understand and explain when to use DataFrame joins and merges
# * Be able to use pd.merge when combining DataFrames based on column values
# * Understand, explain and use a range of DataFrame merge types: outer, inner, left and right
# * Use pd.concat() to stack DataFrames
#
# ## Getting Started
#
# We'll start with a quick section to help us gain practice with concatenating datasets using `pd.concat()`.
#
# ### Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that we have multiple DataFrames to work with, we can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
combined_df = pd.concat([df1,df2,df3])
combined_df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="er1.png">
#
# ### Setting Join Conditions With Concatenation
#
# We can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, we'll execute an inner join. Before we do, we need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` method to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4 = pd.concat([df1,df4],join='inner',axis=1)
df1_and_4
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='er2.png'>
#
# We'll notice that in this case, the results returned contain only the rows with indexes that exist in both tables--rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that we can make full use of the `concat()` functionality in pandas to join DataFrames together--these are just a few of the most common examples pulled from the pandas documentation on the subject.  For a full view of all the ways we can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!

# %% [markdown]
# ## Loading In Data From SQL Database Tables
#
# Now, we'll move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the  [kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table--but not all--correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  We'll make use of these keys to **_join_** the different tables together into a single DataFrame.  We'll also experiment with different types of joins to help us decide exactly what information we want to combine.
#
# Before we can begin working with the database, we'll first need to connect to it.  For this, we'll use the `sqlalchemy` library.
#
# In the cell below:
#
# * Import the `create_engine` module from `sqlalchemy`
# * Create an engine that connects to `sqlite:///database.sqlite`.

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///database.sqlite')

# %% [markdown]
# Now that we've successfully connected to our Database, we'll make use of pandas to read in each table individually.
#
# In the cell below, read in each sql table into separate pandas DataFrames using the `read_sql_table` method.
#
# The first argument should be a string corresponding to the name of the table, and the second argument should be the `engine` object we created in the cell above.
#
# If you're unsure of how to do this, see the [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html).

# %%
cards_df = pd.read_sql_table('cards', engine)
#dust_df = pd.read_sql_table('dust', engine)
entourages_df = pd.read_sql_table('entourages', engine)
mechanics_df = pd.read_sql_table('mechanics', engine)
play_requirements_df = pd.read_sql_table('play_requirements', engine)

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the dataframes we created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the head of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since we are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
cards_df.set_index('card_id')
# Out:
#                               player_class         type  \
# card_id
# KARA_00_07                            MAGE        SPELL
# NEW1_008a                            DRUID        SPELL
# BRM_010t2                            DRUID       MINION
# AT_132                             NEUTRAL       MINION
# OG_141                             NEUTRAL       MINION
# CRED_17                            NEUTRAL       MINION
# OG_337e                            NEUTRAL  ENCHANTMENT
# BRMA08_1H                          NEUTRAL         HERO
# GVG_011a                           NEUTRAL  ENCHANTMENT
# NAX8_02H_TB                        NEUTRAL   HERO_POWER
# AT_131                             NEUTRAL       MINION
# CS2_122e                           NEUTRAL  ENCHANTMENT
# LOEA05_02ha                        NEUTRAL   HERO_POWER
# CS2_102_H1_AT_132                  WARRIOR   HERO_POWER
# CFM_334e                           NEUTRAL  ENCHANTMENT
# EX1_583                            NEUTRAL       MINION
# TB_PickYourFate_11rand             NEUTRAL        SPELL
# LOE_007t                           WARLOCK        SPELL
# CFM_095                            NEUTRAL       MINION
# BRM_018                            PALADIN       MINION
# PRO_001a                           NEUTRAL        SPELL
# BRMA10_5H                          NEUTRAL       MINION
# BRMA11_1                           NEUTRAL         HERO
# OG_027                              SHAMAN        SPELL
# NAX1_01                            NEUTRAL         HERO
# GVG_030                              DRUID       MINION
# CFM_094                            WARLOCK        SPELL
# DS1h_292_H1                         HUNTER   HERO_POWER
# CS2_227                            NEUTRAL       MINION
# KAR_062                            NEUTRAL       MINION
# ...                                    ...          ...
# LOEA12_2                           NEUTRAL   HERO_POWER
# AT_084                             NEUTRAL       MINION
# KARA_00_03                            MAGE         HERO
# BRMA16_3                           NEUTRAL        SPELL
# tt_010a                               MAGE       MINION
# EX1_559                               MAGE       MINION
# EX1_624                             PRIEST        SPELL
# OG_044a                              DRUID       MINION
# AT_044                               DRUID        SPELL
# AT_132_SHAMAN                       SHAMAN   HERO_POWER
# CFM_621t29                         NEUTRAL        SPELL
# EX1_355e                           PALADIN  ENCHANTMENT
# LOEA09_3d                          NEUTRAL   HERO_POWER
# TB_Coopv3_105                      NEUTRAL       MINION
# BRMA13_4                           NEUTRAL   HERO_POWER
# EX1_345t                            PRIEST       MINION
# EX1_009                            NEUTRAL       MINION
# CRED_32                            NEUTRAL       MINION
# FP1_030e                           NEUTRAL  ENCHANTMENT
# TB_PickYourFate_10_Ench            NEUTRAL  ENCHANTMENT
# KARA_05_01hpheroic                 NEUTRAL   HERO_POWER
# BRMA10_3                           NEUTRAL   HERO_POWER
# TB_PickYourFate_10_EnchMinion      NEUTRAL  ENCHANTMENT
# NAX3_02H                           NEUTRAL   HERO_POWER
# AT_083e                            NEUTRAL  ENCHANTMENT
# AT_066e                            WARRIOR  ENCHANTMENT
# CS2_031                               MAGE        SPELL
# OG_195e                            NEUTRAL  ENCHANTMENT
# XXX_111e                           NEUTRAL  ENCHANTMENT
# NAX3_01                            NEUTRAL         HERO
#
#                                                                  name  \
# card_id
# KARA_00_07                                              Astral Portal
# NEW1_008a                                           Ancient Teachings
# BRM_010t2                                          Druid of the Flame
# AT_132                                             Justicar Trueheart
# OG_141                                              Faceless Behemoth
# CRED_17                                                     Rob Pardo
# OG_337e                                            Eve of Destruction
# BRMA08_1H                                          General Drakkisath
# GVG_011a                                                   Shrink Ray
# NAX8_02H_TB                                                   Harvest
# AT_131                                                 Eydis Darkbane
# CS2_122e                                                     Enhanced
# LOEA05_02ha                                       Trogg Hate Minions!
# CS2_102_H1_AT_132                                            Tank Up!
# CFM_334e                                                    Smuggling
# EX1_583                                            Priestess of Elune
# TB_PickYourFate_11rand                             Dire Fate: Murlocs
# LOE_007t                                                      Cursed!
# CFM_095                                               Weasel Tunneler
# BRM_018                                                Dragon Consort
# PRO_001a                                                  I Am Murloc
# BRMA10_5H                                             Chromatic Drake
# BRMA11_1                                      Vaelastrasz the Corrupt
# OG_027                                                         Evolve
# NAX1_01                                                   Anub'Rekhan
# GVG_030                                             Anodized Robo Cub
# CFM_094                                                Felfire Potion
# DS1h_292_H1                                               Steady Shot
# CS2_227                                         Venture Co. Mercenary
# KAR_062                                         Netherspite Historian
# ...                                                               ...
# LOEA12_2                                           Pearl of the Tides
# AT_084                                                  Lance Carrier
# KARA_00_03                                                     Medivh
# BRMA16_3                                                 Sonic Breath
# tt_010a                                                   Spellbender
# EX1_559                                            Archmage Antonidas
# EX1_624                                                     Holy Fire
# OG_044a                                             Druid of the Claw
# AT_044                                                          Mulch
# AT_132_SHAMAN                                            Totemic Slam
# CFM_621t29                                                Mystic Wool
# EX1_355e                                             Blessed Champion
# LOEA09_3d                                              Getting Hungry
# TB_Coopv3_105                                             Raid Healer
# BRMA13_4                                                   Wild Magic
# EX1_345t                                            Shadow of Nothing
# EX1_009                                                 Angry Chicken
# CRED_32                                                  Jerry Mascho
# FP1_030e                                                Necrotic Aura
# TB_PickYourFate_10_Ench                                          Fate
# KARA_05_01hpheroic                                          Trembling
# BRMA10_3                                                  The Rookery
# TB_PickYourFate_10_EnchMinion                                   Bonus
# NAX3_02H                                                     Web Wrap
# AT_083e                                                 Dragonhawkery
# AT_066e                                           Forges of Orgrimmar
# CS2_031                                                     Ice Lance
# OG_195e                                                      Enormous
# XXX_111e                       All Charge, All Windfury, All The Time
# NAX3_01                                                       Maexxna
#
#                                       set  \
# card_id
# KARA_00_07                           KARA
# NEW1_008a                         EXPERT1
# BRM_010t2                             BRM
# AT_132                                TGT
# OG_141                                 OG
# CRED_17                           CREDITS
# OG_337e                                OG
# BRMA08_1H                             BRM
# GVG_011a                              GVG
# NAX8_02H_TB                            TB
# AT_131                                TGT
# CS2_122e                             CORE
# LOEA05_02ha                           LOE
# CS2_102_H1_AT_132              HERO_SKINS
# CFM_334e                            GANGS
# EX1_583                           EXPERT1
# TB_PickYourFate_11rand                 TB
# LOE_007t                              LOE
# CFM_095                             GANGS
# BRM_018                               BRM
# PRO_001a                            PROMO
# BRMA10_5H                             BRM
# BRMA11_1                              BRM
# OG_027                                 OG
# NAX1_01                              NAXX
# GVG_030                               GVG
# CFM_094                             GANGS
# DS1h_292_H1                    HERO_SKINS
# CS2_227                           EXPERT1
# KAR_062                              KARA
# ...                                   ...
# LOEA12_2                              LOE
# AT_084                                TGT
# KARA_00_03                           KARA
# BRMA16_3                              BRM
# tt_010a                           EXPERT1
# EX1_559                           EXPERT1
# EX1_624                           EXPERT1
# OG_044a                           EXPERT1
# AT_044                                TGT
# AT_132_SHAMAN                         TGT
# CFM_621t29                          GANGS
# EX1_355e                          EXPERT1
# LOEA09_3d                             LOE
# TB_Coopv3_105                          TB
# BRMA13_4                              BRM
# EX1_345t                          EXPERT1
# EX1_009                           EXPERT1
# CRED_32                           CREDITS
# FP1_030e                             NAXX
# TB_PickYourFate_10_Ench                TB
# KARA_05_01hpheroic                   KARA
# BRMA10_3                              BRM
# TB_PickYourFate_10_EnchMinion          TB
# NAX3_02H                             NAXX
# AT_083e                               TGT
# AT_066e                               TGT
# CS2_031                           EXPERT1
# OG_195e                                OG
# XXX_111e                            CHEAT
# NAX3_01                              NAXX
#
#                                                                             text  \
# card_id
# KARA_00_07                              Summon a random <b>Legendary</b> minion.
# NEW1_008a                                                           Draw a card.
# BRM_010t2                                                                   None
# AT_132                         <b>Battlecry:</b> Replace your starting Hero P...
# OG_141                                                                      None
# CRED_17                        You can't start a game without this minion in ...
# OG_337e                                                         Stats increased.
# BRMA08_1H                                                                   None
# GVG_011a                                                    -2 Attack this turn.
# NAX8_02H_TB                    <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...
# AT_131                         Whenever <b>you</b> target this minion with a ...
# CS2_122e                          Raid Leader is granting this minion +1 Attack.
# LOEA05_02ha                    <b>Passive Hero Power</b>\n Enemy minions cost...
# CS2_102_H1_AT_132                               <b>Hero Power</b>\nGain 4 Armor.
# CFM_334e                                            +2/+2 from Smuggler's Crate.
# EX1_583                         <b>Battlecry:</b> Restore 4 Health to your hero.
# TB_PickYourFate_11rand               Turn each minion in play into a 1/1 Murloc.
# LOE_007t                       While this is in your hand, take 2 damage at t...
# CFM_095                        <b>Deathrattle:</b> Shuffle this minion into y...
# BRM_018                        <b>Battlecry:</b> The next Dragon you play cos...
# PRO_001a                                Summon three, four, or five 1/1 Murlocs.
# BRMA10_5H                                                                   None
# BRMA11_1                                                                    None
# OG_027                         Transform your minions into random minions tha...
# NAX1_01                                                                     None
# GVG_030                        <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...
# CFM_094                                        Deal $5 damage to all characters.
# DS1h_292_H1                    <b>Hero Power</b>\nDeal $2 damage to the enemy...
# CS2_227                                              Your minions cost (3) more.
# KAR_062                        <b>Battlecry:</b> If you're holding a Dragon, ...
# ...                                                                          ...
# LOEA12_2                       At the end of your turn, replace all minions w...
# AT_084                         <b>Battlecry:</b> Give a friendly minion +2 At...
# KARA_00_03                                                                  None
# BRMA16_3                       Deal $3 damage to a minion. Give your weapon +...
# tt_010a                                                                     None
# EX1_559                        Whenever you cast a spell, add a 'Fireball' sp...
# EX1_624                          Deal $5 damage. Restore #5 Health to your hero.
# OG_044a                                              <b>Charge</b>\n<b>Taunt</b>
# AT_044                         Destroy a minion.\nAdd a random minion to your...
# AT_132_SHAMAN                  <b>Hero Power</b>\nSummon a Totem of your choice.
# CFM_621t29                                 Transform all minions into 1/1 Sheep.
# EX1_355e                                  This minion's Attack has been doubled.
# LOEA09_3d                           <b>Hero Power</b>\nSummon a 5/1 Hungry Naga.
# TB_Coopv3_105                  Whenever your hero is healed, also heal your t...
# BRMA13_4                       <b>Hero Power</b>\nPut a random spell from you...
# EX1_345t                        Mindgames whiffed! Your opponent had no minions!
# EX1_009                                                <b>Enrage:</b> +5 Attack.
# CRED_32                        At the start of your turn, deal 1 damage. If t...
# FP1_030e                                    Your spells cost (5) more this turn.
# TB_PickYourFate_10_Ench                                                     None
# KARA_05_01hpheroic             <b>Passive Hero Power</b> Minions cost (1). En...
# BRMA10_3                       <b>Hero Power</b>\nGive all Corrupted Eggs +1 ...
# TB_PickYourFate_10_EnchMinion          Your <b>Battlecry</b> minions have +1/+1.
# NAX3_02H                       <b>Hero Power</b>\nReturn 2 random enemy minio...
# AT_083e                                               <b>Windfury</b> this turn.
# AT_066e                                                        Increased Attack.
# CS2_031                        <b>Freeze</b> a character. If it was already <...
# OG_195e                                                                   +2/+2.
# XXX_111e                       Your minions always have <b>Charge</b> and <b>...
# NAX3_01                                                                     None
#
#                                cost  attack  health     rarity  collectible  \
# card_id
# KARA_00_07                      1.0     NaN     NaN       None          NaN
# NEW1_008a                       0.0     NaN     NaN       None          NaN
# BRM_010t2                       3.0     2.0     5.0     COMMON          NaN
# AT_132                          6.0     6.0     3.0  LEGENDARY          1.0
# OG_141                         10.0    10.0    10.0     COMMON          1.0
# CRED_17                         9.0     9.0     9.0  LEGENDARY          NaN
# OG_337e                         NaN     NaN     NaN       None          NaN
# BRMA08_1H                       NaN     NaN    50.0       None          NaN
# GVG_011a                        NaN     NaN     NaN       None          NaN
# NAX8_02H_TB                     2.0     NaN     NaN       None          NaN
# AT_131                          3.0     3.0     4.0  LEGENDARY          1.0
# CS2_122e                        NaN     NaN     NaN       None          NaN
# LOEA05_02ha                     0.0     NaN     NaN       None          NaN
# CS2_102_H1_AT_132               2.0     NaN     NaN       None          NaN
# CFM_334e                        NaN     NaN     NaN       None          NaN
# EX1_583                         6.0     5.0     4.0     COMMON          1.0
# TB_PickYourFate_11rand          0.0     NaN     NaN       None          NaN
# LOE_007t                        2.0     NaN     NaN       None          NaN
# CFM_095                         1.0     1.0     1.0       EPIC          1.0
# BRM_018                         5.0     5.0     5.0       RARE          1.0
# PRO_001a                        4.0     NaN     NaN       None          NaN
# BRMA10_5H                       4.0     7.0     7.0       None          NaN
# BRMA11_1                        NaN     NaN    30.0       None          NaN
# OG_027                          1.0     NaN     NaN       RARE          1.0
# NAX1_01                         NaN     NaN    30.0       None          NaN
# GVG_030                         2.0     2.0     2.0     COMMON          1.0
# CFM_094                         6.0     NaN     NaN       RARE          1.0
# DS1h_292_H1                     2.0     NaN     NaN       FREE          NaN
# CS2_227                         5.0     7.0     6.0     COMMON          1.0
# KAR_062                         2.0     1.0     3.0     COMMON          1.0
# ...                             ...     ...     ...        ...          ...
# LOEA12_2                        0.0     NaN     NaN       None          NaN
# AT_084                          2.0     1.0     2.0     COMMON          1.0
# KARA_00_03                      NaN     NaN    30.0       None          NaN
# BRMA16_3                        4.0     NaN     NaN       None          NaN
# tt_010a                         1.0     1.0     3.0       EPIC          NaN
# EX1_559                         7.0     5.0     7.0  LEGENDARY          1.0
# EX1_624                         6.0     NaN     NaN       RARE          1.0
# OG_044a                         5.0     4.0     6.0     COMMON          NaN
# AT_044                          3.0     NaN     NaN       EPIC          1.0
# AT_132_SHAMAN                   2.0     NaN     NaN       None          NaN
# CFM_621t29                     10.0     NaN     NaN       None          NaN
# EX1_355e                        NaN     NaN     NaN       None          NaN
# LOEA09_3d                       0.0     NaN     NaN       None          NaN
# TB_Coopv3_105                   4.0     0.0     7.0       None          NaN
# BRMA13_4                        1.0     NaN     NaN       None          NaN
# EX1_345t                        0.0     0.0     1.0       EPIC          NaN
# EX1_009                         1.0     1.0     1.0       RARE          1.0
# CRED_32                         2.0     3.0     2.0  LEGENDARY          NaN
# FP1_030e                        NaN     NaN     NaN       None          NaN
# TB_PickYourFate_10_Ench         NaN     NaN     NaN       None          NaN
# KARA_05_01hpheroic              0.0     NaN     NaN     COMMON          NaN
# BRMA10_3                        1.0     NaN     NaN       None          NaN
# TB_PickYourFate_10_EnchMinion   NaN     NaN     NaN       None          NaN
# NAX3_02H                        0.0     NaN     NaN       None          NaN
# AT_083e                         NaN     NaN     NaN       None          NaN
# AT_066e                         NaN     NaN     NaN       None          NaN
# CS2_031                         1.0     NaN     NaN     COMMON          1.0
# OG_195e                         NaN     NaN     NaN       None          NaN
# XXX_111e                        NaN     NaN     NaN       None          NaN
# NAX3_01                         NaN     NaN    30.0       None          NaN
#
#                                                                           flavor  \
# card_id
# KARA_00_07                                                                  None
# NEW1_008a                                                                   None
# BRM_010t2                                                                   None
# AT_132                         It's like putting racing stripes and a giant s...
# OG_141                         Rejected names: Forty-Foot Faceless, Big ol' N...
# CRED_17                                                                     None
# OG_337e                                                                     None
# BRMA08_1H                                                                   None
# GVG_011a                                                                    None
# NAX8_02H_TB                                                                 None
# AT_131                                    HATES being called "the wonder twins".
# CS2_122e                                                                    None
# LOEA05_02ha                                                                 None
# CS2_102_H1_AT_132                                                           None
# CFM_334e                                                                    None
# EX1_583                        If she threatens to "moon" you, it's not what ...
# TB_PickYourFate_11rand                                                      None
# LOE_007t                                                                    None
# CFM_095                        He's the reason the First Bank of Gadgetzan ha...
# BRM_018                        Everybody wants someone to snuggle with. Even ...
# PRO_001a                                                                    None
# BRMA10_5H                                                                   None
# BRMA11_1                                                                    None
# OG_027                         So you say you want an evolution. Well, you kn...
# NAX1_01                                                                     None
# GVG_030                        It's adorable! AND OH MY GOODNESS WHY IS IT EA...
# CFM_094                        Kazakus has a squad of imps bottling Felfire r...
# DS1h_292_H1                                                                 None
# CS2_227                                   No Job is too big.  No fee is too big.
# KAR_062                        She can tell you all about the history of peop...
# ...                                                                          ...
# LOEA12_2                                                                    None
# AT_084                         Lance Carrier is an obscure entry level positi...
# KARA_00_03                                                                  None
# BRMA16_3                                                                    None
# tt_010a                                                                     None
# EX1_559                        Antonidas was the Grand Magus of the Kirin Tor...
# EX1_624                                           Often followed by Holy Smokes!
# OG_044a                                                                     None
# AT_044                            Is this a noun or a verb?  We will never know.
# AT_132_SHAMAN                                                               None
# CFM_621t29                                                                  None
# EX1_355e                                                                    None
# LOEA09_3d                                                                   None
# TB_Coopv3_105                                                               None
# BRMA13_4                                                                    None
# EX1_345t                                                                    None
# EX1_009                        There is no beast more frightening (or ridicul...
# CRED_32                                                                     None
# FP1_030e                                                                    None
# TB_PickYourFate_10_Ench                                                     None
# KARA_05_01hpheroic                                                          None
# BRMA10_3                                                                    None
# TB_PickYourFate_10_EnchMinion                                               None
# NAX3_02H                                                                    None
# AT_083e                                                                     None
# AT_066e                                                                     None
# CS2_031                        The trick is not to break the lance.  Otherwis...
# OG_195e                                                                     None
# XXX_111e                                                                    None
# NAX3_01                                                                     None
#
#                                      race  \
# card_id
# KARA_00_07                           None
# NEW1_008a                            None
# BRM_010t2                           BEAST
# AT_132                               None
# OG_141                               None
# CRED_17                              None
# OG_337e                              None
# BRMA08_1H                            None
# GVG_011a                             None
# NAX8_02H_TB                          None
# AT_131                               None
# CS2_122e                             None
# LOEA05_02ha                          None
# CS2_102_H1_AT_132                    None
# CFM_334e                             None
# EX1_583                              None
# TB_PickYourFate_11rand               None
# LOE_007t                             None
# CFM_095                             BEAST
# BRM_018                            DRAGON
# PRO_001a                             None
# BRMA10_5H                          DRAGON
# BRMA11_1                             None
# OG_027                               None
# NAX1_01                              None
# GVG_030                        MECHANICAL
# CFM_094                              None
# DS1h_292_H1                          None
# CS2_227                              None
# KAR_062                              None
# ...                                   ...
# LOEA12_2                             None
# AT_084                               None
# KARA_00_03                           None
# BRMA16_3                             None
# tt_010a                              None
# EX1_559                              None
# EX1_624                              None
# OG_044a                             BEAST
# AT_044                               None
# AT_132_SHAMAN                        None
# CFM_621t29                           None
# EX1_355e                             None
# LOEA09_3d                            None
# TB_Coopv3_105                        None
# BRMA13_4                             None
# EX1_345t                             None
# EX1_009                             BEAST
# CRED_32                              None
# FP1_030e                             None
# TB_PickYourFate_10_Ench              None
# KARA_05_01hpheroic                   None
# BRMA10_3                             None
# TB_PickYourFate_10_EnchMinion        None
# NAX3_02H                             None
# AT_083e                              None
# AT_066e                              None
# CS2_031                              None
# OG_195e                              None
# XXX_111e                             None
# NAX3_01                              None
#
#                                                                      how_to_earn  \
# card_id
# KARA_00_07                                                                  None
# NEW1_008a                                                                   None
# BRM_010t2                                                                   None
# AT_132                                                                      None
# OG_141                                                                      None
# CRED_17                                                                     None
# OG_337e                                                                     None
# BRMA08_1H                                                                   None
# GVG_011a                                                                    None
# NAX8_02H_TB                                                                 None
# AT_131                                                                      None
# CS2_122e                                                                    None
# LOEA05_02ha                                                                 None
# CS2_102_H1_AT_132                                                           None
# CFM_334e                                                                    None
# EX1_583                                                                     None
# TB_PickYourFate_11rand                                                      None
# LOE_007t                                                                    None
# CFM_095                                                                     None
# BRM_018                        Unlocked in Blackrock Spire, in the Blackrock ...
# PRO_001a                                                                    None
# BRMA10_5H                                                                   None
# BRMA11_1                                                                    None
# OG_027                                                                      None
# NAX1_01                                                                     None
# GVG_030                                                                     None
# CFM_094                                                                     None
# DS1h_292_H1                                                                 None
# CS2_227                                                                     None
# KAR_062                         Unlocked in the Spire, in One Night in Karazhan.
# ...                                                                          ...
# LOEA12_2                                                                    None
# AT_084                                                                      None
# KARA_00_03                                                                  None
# BRMA16_3                                                                    None
# tt_010a                                                                     None
# EX1_559                                                                     None
# EX1_624                                                                     None
# OG_044a                                                                     None
# AT_044                                                                      None
# AT_132_SHAMAN                                                               None
# CFM_621t29                                                                  None
# EX1_355e                                                                    None
# LOEA09_3d                                                                   None
# TB_Coopv3_105                                                               None
# BRMA13_4                                                                    None
# EX1_345t                                                                    None
# EX1_009                                                                     None
# CRED_32                                                                     None
# FP1_030e                                                                    None
# TB_PickYourFate_10_Ench                                                     None
# KARA_05_01hpheroic                                                          None
# BRMA10_3                                                                    None
# TB_PickYourFate_10_EnchMinion                                               None
# NAX3_02H                                                                    None
# AT_083e                                                                     None
# AT_066e                                                                     None
# CS2_031                                                                     None
# OG_195e                                                                     None
# XXX_111e                                                                    None
# NAX3_01                                                                     None
#
#                                                               how_to_earn_golden  \
# card_id
# KARA_00_07                                                                  None
# NEW1_008a                                                                   None
# BRM_010t2                                                                   None
# AT_132                                                                      None
# OG_141                                                                      None
# CRED_17                                                                     None
# OG_337e                                                                     None
# BRMA08_1H                                                                   None
# GVG_011a                                                                    None
# NAX8_02H_TB                                                                 None
# AT_131                                                                      None
# CS2_122e                                                                    None
# LOEA05_02ha                                                                 None
# CS2_102_H1_AT_132                                                           None
# CFM_334e                                                                    None
# EX1_583                                                                     None
# TB_PickYourFate_11rand                                                      None
# LOE_007t                                                                    None
# CFM_095                                                                     None
# BRM_018                        Crafting unlocked in Blackrock Spire, in the B...
# PRO_001a                                                                    None
# BRMA10_5H                                                                   None
# BRMA11_1                                                                    None
# OG_027                                                                      None
# NAX1_01                                                                     None
# GVG_030                                                                     None
# CFM_094                                                                     None
# DS1h_292_H1                                                                 None
# CS2_227                                                                     None
# KAR_062                        Crafting unlocked in the Spire, in One Night i...
# ...                                                                          ...
# LOEA12_2                                                                    None
# AT_084                                                                      None
# KARA_00_03                                                                  None
# BRMA16_3                                                                    None
# tt_010a                                                                     None
# EX1_559                                                                     None
# EX1_624                                                                     None
# OG_044a                                                                     None
# AT_044                                                                      None
# AT_132_SHAMAN                                                               None
# CFM_621t29                                                                  None
# EX1_355e                                                                    None
# LOEA09_3d                                                                   None
# TB_Coopv3_105                                                               None
# BRMA13_4                                                                    None
# EX1_345t                                                                    None
# EX1_009                                                                     None
# CRED_32                                                                     None
# FP1_030e                                                                    None
# TB_PickYourFate_10_Ench                                                     None
# KARA_05_01hpheroic                                                          None
# BRMA10_3                                                                    None
# TB_PickYourFate_10_EnchMinion                                               None
# NAX3_02H                                                                    None
# AT_083e                                                                     None
# AT_066e                                                                     None
# CS2_031                                                                     None
# OG_195e                                                                     None
# XXX_111e                                                                    None
# NAX3_01                                                                     None
#
#                               targeting_arrow_text faction  durability
# card_id
# KARA_00_07                                    None    None         NaN
# NEW1_008a                                     None    None         NaN
# BRM_010t2                                     None    None         NaN
# AT_132                                        None    None         NaN
# OG_141                                        None    None         NaN
# CRED_17                                       None    None         NaN
# OG_337e                                       None    None         NaN
# BRMA08_1H                                     None    None         NaN
# GVG_011a                                      None    None         NaN
# NAX8_02H_TB                                   None    None         NaN
# AT_131                                        None    None         NaN
# CS2_122e                                      None    None         NaN
# LOEA05_02ha                                   None    None         NaN
# CS2_102_H1_AT_132                             None    None         NaN
# CFM_334e                                      None    None         NaN
# EX1_583                                       None    None         NaN
# TB_PickYourFate_11rand                        None    None         NaN
# LOE_007t                                      None    None         NaN
# CFM_095                                       None    None         NaN
# BRM_018                                       None    None         NaN
# PRO_001a                                      None    None         NaN
# BRMA10_5H                                     None    None         NaN
# BRMA11_1                                      None    None         NaN
# OG_027                                        None    None         NaN
# NAX1_01                                       None    None         NaN
# GVG_030                                       None    None         NaN
# CFM_094                                       None    None         NaN
# DS1h_292_H1                                   None    None         NaN
# CS2_227                                       None   HORDE         NaN
# KAR_062                                       None    None         NaN
# ...                                            ...     ...         ...
# LOEA12_2                                      None    None         NaN
# AT_084                             Give +2 Attack.    None         NaN
# KARA_00_03                                    None    None         NaN
# BRMA16_3                                      None    None         NaN
# tt_010a                                       None    None         NaN
# EX1_559                                       None    None         NaN
# EX1_624                                       None    None         NaN
# OG_044a                                       None    None         NaN
# AT_044                                        None    None         NaN
# AT_132_SHAMAN                                 None    None         NaN
# CFM_621t29                                    None    None         NaN
# EX1_355e                                      None    None         NaN
# LOEA09_3d                                     None    None         NaN
# TB_Coopv3_105                                 None    None         NaN
# BRMA13_4                                      None    None         NaN
# EX1_345t                                      None    None         NaN
# EX1_009                                       None    None         NaN
# CRED_32                                       None    None         NaN
# FP1_030e                                      None    None         NaN
# TB_PickYourFate_10_Ench                       None    None         NaN
# KARA_05_01hpheroic                            None    None         NaN
# BRMA10_3                                      None    None         NaN
# TB_PickYourFate_10_EnchMinion                 None    None         NaN
# NAX3_02H                                      None    None         NaN
# AT_083e                                       None    None         NaN
# AT_066e                                       None    None         NaN
# CS2_031                                       None    None         NaN
# OG_195e                                       None    None         NaN
# XXX_111e                                      None    None         NaN
# NAX3_01                                       None    None         NaN
#
# [2819 rows x 17 columns]

# %%
entourages_df.set_index('card_id')
# Out:
#                              entourage_card_id
# card_id
# KAR_A10_22                          KAR_A10_09
# KAR_A10_22                          KAR_A10_02
# KAR_A10_22                          KAR_A10_08
# KAR_A10_22                          KAR_A10_04
# KAR_A10_22                          KAR_A10_05
# TBST_006                              TBST_003
# TBST_006                              TBST_002
# TBST_006                              TBST_001
# BRMA14_10H                            BRMA14_3
# BRMA14_10H                           BRMA14_5H
# BRMA14_10H                           BRMA14_7H
# BRMA14_10H                           BRMA14_9H
# BRMA09_3                              BRMA09_2
# BRMA09_3                              BRMA09_4
# BRMA09_3                              BRMA09_5
# KARA_06_03hp                        KARA_06_01
# BRMA12_2                              BRMA12_6
# BRMA12_2                              BRMA12_5
# BRMA12_2                              BRMA12_7
# BRMA12_2                              BRMA12_4
# BRMA12_2                              BRMA12_3
# TB_PickYourFate_2nd          TB_PickYourFate_1
# TB_PickYourFate_2nd          TB_PickYourFate_4
# TB_PickYourFate_2nd      TB_PickYourFate_7_2nd
# TB_PickYourFate_2nd          TB_PickYourFate_3
# TB_PickYourFate_2nd      TB_PickYourFate_6_2nd
# TB_PickYourFate_2nd     TB_PickYourFate_11rand
# TB_001                               BRMA14_10
# TB_001                              BRMA14_10H
# TB_001                                BRMA09_4
# ...                                        ...
# LOEA16_16H                           LOEA16_10
# LOEA16_16H                           LOEA16_11
# LOEA16_16H                           LOEA16_14
# LOEA16_16H                           LOEA16_15
# LOEA16_16H                            LOEA16_6
# LOEA16_16H                            LOEA16_7
# LOEA16_16H                            LOEA16_9
# LOEA16_16H                           LOEA16_12
# LOEA16_16H                           LOEA16_13
# LOEA16_16H                            LOEA16_8
# TBUD_1                                 CS1_042
# TBUD_1                                 CS2_171
# BRMA13_3H                             BRMA13_8
# BRMA13_3H                             BRMA13_7
# BRMA13_3H                             BRMA13_6
# BRMA13_3H                             BRMA13_5
# TB_MechWar_CommonCards                 GVG_069
# TB_MechWar_CommonCards                 GVG_079
# TB_MechWar_CommonCards                 GVG_034
# TB_MechWar_CommonCards                 GVG_048
# TB_MechWar_CommonCards                 GVG_049
# TB_MechWar_CommonCards                 GVG_088
# KARA_00_10                             EX1_294
# KARA_00_10                             FP1_018
# KARA_00_10                              AT_002
# KARA_00_10                             EX1_287
# KARA_00_10                              tt_010
# KARA_00_10                             EX1_295
# KARA_00_10                             EX1_289
# KARA_00_10                             EX1_594
#
# [328 rows x 1 columns]

# %%
mechanics_df.set_index('card_id')
# Out:
#                                mechanic
# card_id
# AT_132                        BATTLECRY
# GVG_011a            TAG_ONE_TURN_EFFECT
# EX1_583                       BATTLECRY
# LOE_007t                      EVIL_GLOW
# LOE_007t             ImmuneToSpellpower
# CFM_095                     DEATHRATTLE
# BRM_018                       BATTLECRY
# GVG_030                      CHOOSE_ONE
# GVG_030                           TAUNT
# CS2_227                            AURA
# KAR_062                       BATTLECRY
# CFM_712_t17                  JADE_GOLEM
# BRM_011t            TAG_ONE_TURN_EFFECT
# BRMA10_3H                  AI_MUST_PLAY
# KAR_710m                          TAUNT
# EX1_295o            TAG_ONE_TURN_EFFECT
# OG_158                      DEATHRATTLE
# LOE_110t                        TOPDECK
# LOE_110t             ImmuneToSpellpower
# BRMA13_4H                  AI_MUST_PLAY
# EX1_145o            TAG_ONE_TURN_EFFECT
# LOEA09_2e           TAG_ONE_TURN_EFFECT
# EX1_570e            TAG_ONE_TURN_EFFECT
# GVG_069                       BATTLECRY
# hexfrog                           TAUNT
# OG_145                    DIVINE_SHIELD
# OG_145                            TAUNT
# AT_090                          INSPIRE
# AT_060                           SECRET
# TB_MechWar_Minion1                TAUNT
# ...                                 ...
# EX1_284                       BATTLECRY
# LOE_038                            AURA
# AT_083                          INSPIRE
# TB_CoOpv3_BOSS2e                ENRAGED
# GVG_009                       BATTLECRY
# CFM_338                       BATTLECRY
# GVG_097                       BATTLECRY
# GVG_097                           TAUNT
# CFM_852                       BATTLECRY
# LOE_020                       BATTLECRY
# CFM_781                         STEALTH
# GVG_090                       BATTLECRY
# GVG_120                       BATTLECRY
# EX1_055o            TAG_ONE_TURN_EFFECT
# CFM_321                       BATTLECRY
# EX1_082                       BATTLECRY
# FP1_017                            AURA
# FP1_001                     DEATHRATTLE
# AT_089                          INSPIRE
# CFM_646                     DEATHRATTLE
# AT_084                        BATTLECRY
# OG_044a                          CHARGE
# OG_044a                           TAUNT
# LOEA09_3d                  AI_MUST_PLAY
# BRMA13_4                   AI_MUST_PLAY
# EX1_009                         ENRAGED
# BRMA10_3                   AI_MUST_PLAY
# NAX3_02H                   AI_MUST_PLAY
# AT_083e             TAG_ONE_TURN_EFFECT
# CS2_031                          FREEZE
#
# [1079 rows x 1 columns]

# %%
play_requirements_df.set_index('card_id')
# Out:
#                                 play_requirement  value
# card_id
# KARA_00_07                  REQ_NUM_MINION_SLOTS      1
# PRO_001a                    REQ_NUM_MINION_SLOTS      1
# NAX1_01                     REQ_NUM_MINION_SLOTS      1
# DS1h_292_H1                      REQ_STEADY_SHOT      0
# DS1h_292_H1             REQ_MINION_OR_ENEMY_HERO      0
# KAR_076                       REQ_TARGET_TO_PLAY      0
# AT_024                        REQ_TARGET_TO_PLAY      0
# AT_024                      REQ_TARGET_WITH_RACE     15
# AT_024                         REQ_MINION_TARGET      0
# BRMA06_2                    REQ_NUM_MINION_SLOTS      1
# NAX5_02                REQ_MINIMUM_ENEMY_MINIONS      1
# OG_080c                      REQ_FRIENDLY_TARGET      0
# OG_080c                       REQ_TARGET_TO_PLAY      0
# OG_080c                        REQ_MINION_TARGET      0
# CS2_039                       REQ_TARGET_TO_PLAY      0
# CS2_039                        REQ_MINION_TARGET      0
# TB_KaraPortal_002              REQ_MINION_TARGET      0
# CS2_094                       REQ_TARGET_TO_PLAY      0
# TB_SPT_DPromoHP                REQ_MINION_TARGET      0
# BRMA15_3                    REQ_NUM_MINION_SLOTS      1
# CS2_141                  REQ_TARGET_IF_AVAILABLE      0
# CS2_141                       REQ_NONSELF_TARGET      0
# CS2_063                       REQ_TARGET_TO_PLAY      0
# CS2_063                        REQ_MINION_TARGET      0
# CS2_063                         REQ_ENEMY_TARGET      0
# GVG_055e                     REQ_FRIENDLY_TARGET      0
# TB_006                        REQ_TARGET_TO_PLAY      0
# TB_006                         REQ_MINION_TARGET      0
# CFM_621t21             REQ_MINIMUM_TOTAL_MINIONS      1
# LOEA06_04h                    REQ_TARGET_TO_PLAY      0
# ...                                          ...    ...
# GVG_011                        REQ_MINION_TARGET      0
# CFM_061                       REQ_TARGET_TO_PLAY      0
# AT_132_HUNTER                    REQ_STEADY_SHOT      0
# AT_132_HUNTER           REQ_MINION_OR_ENEMY_HERO      0
# GVG_047                        REQ_MINION_TARGET      0
# GVG_047                         REQ_ENEMY_TARGET      0
# EX1_278                       REQ_TARGET_TO_PLAY      0
# CS2_012                       REQ_TARGET_TO_PLAY      0
# CS2_012                         REQ_ENEMY_TARGET      0
# EX1_578                       REQ_TARGET_TO_PLAY      0
# EX1_578                        REQ_MINION_TARGET      0
# KARA_00_10         REQ_SECRET_CAP_FOR_NON_SECRET      0
# KARA_13_11             REQ_MINIMUM_ENEMY_MINIONS      2
# GVG_120                  REQ_TARGET_IF_AVAILABLE      0
# GVG_120                     REQ_TARGET_WITH_RACE     20
# LOEA02_10a                  REQ_NUM_MINION_SLOTS      1
# CS1_130                       REQ_TARGET_TO_PLAY      0
# AT_025                 REQ_MINIMUM_ENEMY_MINIONS      2
# CS2_061                       REQ_TARGET_TO_PLAY      0
# AT_084                       REQ_FRIENDLY_TARGET      0
# AT_084                   REQ_TARGET_IF_AVAILABLE      0
# AT_084                         REQ_MINION_TARGET      0
# BRMA16_3                     REQ_WEAPON_EQUIPPED      0
# BRMA16_3                      REQ_TARGET_TO_PLAY      0
# BRMA16_3                       REQ_MINION_TARGET      0
# EX1_624                       REQ_TARGET_TO_PLAY      0
# AT_044                        REQ_TARGET_TO_PLAY      0
# AT_044                         REQ_MINION_TARGET      0
# AT_132_SHAMAN               REQ_NUM_MINION_SLOTS      1
# CS2_031                       REQ_TARGET_TO_PLAY      0
#
# [776 rows x 2 columns]

# %% [markdown]
# ### Executing Joins
#
# Now that we have the tables loaded correctly, we're going to execute some joins. There are 4 different kinds of joins, which can best be visualized with venn diagrams:
#
# <img src='joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table.  The left table is the table we are working with, and the right table is the table we want to join to the table we are working with.  We'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table we want to join with, `mechanics_df`
# * The `how` parameter set to the type of join we want, `'inner'`

# %%
cards_with_mechanics_df = cards_df.join(mechanics_df,how='inner',lsuffix='_left', rsuffix='_right')
cards_with_mechanics_df
# Out:
#                     card_id_left player_class         type  \
# 0                     KARA_00_07         MAGE        SPELL
# 1                      NEW1_008a        DRUID        SPELL
# 2                      BRM_010t2        DRUID       MINION
# 3                         AT_132      NEUTRAL       MINION
# 4                         OG_141      NEUTRAL       MINION
# 5                        CRED_17      NEUTRAL       MINION
# 6                        OG_337e      NEUTRAL  ENCHANTMENT
# 7                      BRMA08_1H      NEUTRAL         HERO
# 8                       GVG_011a      NEUTRAL  ENCHANTMENT
# 9                    NAX8_02H_TB      NEUTRAL   HERO_POWER
# 10                        AT_131      NEUTRAL       MINION
# 11                      CS2_122e      NEUTRAL  ENCHANTMENT
# 12                   LOEA05_02ha      NEUTRAL   HERO_POWER
# 13             CS2_102_H1_AT_132      WARRIOR   HERO_POWER
# 14                      CFM_334e      NEUTRAL  ENCHANTMENT
# 15                       EX1_583      NEUTRAL       MINION
# 16        TB_PickYourFate_11rand      NEUTRAL        SPELL
# 17                      LOE_007t      WARLOCK        SPELL
# 18                       CFM_095      NEUTRAL       MINION
# 19                       BRM_018      PALADIN       MINION
# 20                      PRO_001a      NEUTRAL        SPELL
# 21                     BRMA10_5H      NEUTRAL       MINION
# 22                      BRMA11_1      NEUTRAL         HERO
# 23                        OG_027       SHAMAN        SPELL
# 24                       NAX1_01      NEUTRAL         HERO
# 25                       GVG_030        DRUID       MINION
# 26                       CFM_094      WARLOCK        SPELL
# 27                   DS1h_292_H1       HUNTER   HERO_POWER
# 28                       CS2_227      NEUTRAL       MINION
# 29                       KAR_062      NEUTRAL       MINION
# ...                          ...          ...          ...
# 1049                      AT_017      NEUTRAL       MINION
# 1050                    LOEA12_1      NEUTRAL         HERO
# 1051                     GVG_035        DRUID       MINION
# 1052                     OG_104e      NEUTRAL  ENCHANTMENT
# 1053                     CS2_119      NEUTRAL       MINION
# 1054                     LOE_003         MAGE       MINION
# 1055                    LOE_113e      NEUTRAL  ENCHANTMENT
# 1056                      OG_284      NEUTRAL       MINION
# 1057                     EX1_611       HUNTER        SPELL
# 1058                      OG_340      NEUTRAL       MINION
# 1059                      OG_323      NEUTRAL       MINION
# 1060                     NAX8_03      NEUTRAL       MINION
# 1061                   LOE_089t3      NEUTRAL       MINION
# 1062                    TU4e_001       HUNTER         HERO
# 1063                     GVG_031        DRUID        SPELL
# 1064                     EX1_558      NEUTRAL       MINION
# 1065                     EX1_116      NEUTRAL       MINION
# 1066  TB_MechWar_Boss1_HeroPower      NEUTRAL   HERO_POWER
# 1067                   LOEA07_09      NEUTRAL       MINION
# 1068                      AT_114      NEUTRAL       MINION
# 1069           TB_PickYourFate_6      NEUTRAL        SPELL
# 1070                    AT_074e2      PALADIN  ENCHANTMENT
# 1071            KARA_09_07heroic      NEUTRAL        SPELL
# 1072                      AT_021      WARLOCK       MINION
# 1073                    GAME_004      NEUTRAL  ENCHANTMENT
# 1074              AT_132_SHAMANb       SHAMAN       MINION
# 1075                     BRM_014       HUNTER       MINION
# 1076                    CFM_617e      NEUTRAL  ENCHANTMENT
# 1077                   LOEA16_3e      NEUTRAL  ENCHANTMENT
# 1078                     CS2_121      NEUTRAL       MINION
#
#                          name         set  \
# 0               Astral Portal        KARA
# 1           Ancient Teachings     EXPERT1
# 2          Druid of the Flame         BRM
# 3          Justicar Trueheart         TGT
# 4           Faceless Behemoth          OG
# 5                   Rob Pardo     CREDITS
# 6          Eve of Destruction          OG
# 7          General Drakkisath         BRM
# 8                  Shrink Ray         GVG
# 9                     Harvest          TB
# 10             Eydis Darkbane         TGT
# 11                   Enhanced        CORE
# 12        Trogg Hate Minions!         LOE
# 13                   Tank Up!  HERO_SKINS
# 14                  Smuggling       GANGS
# 15         Priestess of Elune     EXPERT1
# 16         Dire Fate: Murlocs          TB
# 17                    Cursed!         LOE
# 18            Weasel Tunneler       GANGS
# 19             Dragon Consort         BRM
# 20                I Am Murloc       PROMO
# 21            Chromatic Drake         BRM
# 22    Vaelastrasz the Corrupt         BRM
# 23                     Evolve          OG
# 24                Anub'Rekhan        NAXX
# 25          Anodized Robo Cub         GVG
# 26             Felfire Potion       GANGS
# 27                Steady Shot  HERO_SKINS
# 28      Venture Co. Mercenary     EXPERT1
# 29      Netherspite Historian        KARA
# ...                       ...         ...
# 1049        Twilight Guardian         TGT
# 1050             Lady Naz'jar         LOE
# 1051                  Malorne         GVG
# 1052     Embracing the Shadow          OG
# 1053            Oasis Snapjaw        CORE
# 1054        Ethereal Conjurer         LOE
# 1055      Mrglllraawrrrglrur!         LOE
# 1056       Twilight Geomancer          OG
# 1057            Freezing Trap     EXPERT1
# 1058    Soggoth the Slitherer          OG
# 1059         Polluted Hoarder          OG
# 1060      Unrelenting Trainee        NAXX
# 1061             Grumbly Runt         LOE
# 1062        Illidan Stormrage    MISSIONS
# 1063                  Recycle         GVG
# 1064           Harrison Jones     EXPERT1
# 1065           Leeroy Jenkins     EXPERT1
# 1066     Hello! Hello! Hello!          TB
# 1067            Chasing Trogg         LOE
# 1068             Evil Heckler         TGT
# 1069            Fate: Portals          TB
# 1070        Seal of Champions         TGT
# 1071               Steal Life        KARA
# 1072      Tiny Knight of Evil         TGT
# 1073                      AFK        CORE
# 1074            Searing Totem         TGT
# 1075               Core Rager         BRM
# 1076        Visions of Hypnos       GANGS
# 1077         Lantern of Power         LOE
# 1078          Frostwolf Grunt        CORE
#
#                                                    text  cost  attack  health  \
# 0              Summon a random <b>Legendary</b> minion.   1.0     NaN     NaN
# 1                                          Draw a card.   0.0     NaN     NaN
# 2                                                  None   3.0     2.0     5.0
# 3     <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0     3.0
# 4                                                  None  10.0    10.0    10.0
# 5     You can't start a game without this minion in ...   9.0     9.0     9.0
# 6                                      Stats increased.   NaN     NaN     NaN
# 7                                                  None   NaN     NaN    50.0
# 8                                  -2 Attack this turn.   NaN     NaN     NaN
# 9     <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...   2.0     NaN     NaN
# 10    Whenever <b>you</b> target this minion with a ...   3.0     3.0     4.0
# 11       Raid Leader is granting this minion +1 Attack.   NaN     NaN     NaN
# 12    <b>Passive Hero Power</b>\n Enemy minions cost...   0.0     NaN     NaN
# 13                     <b>Hero Power</b>\nGain 4 Armor.   2.0     NaN     NaN
# 14                         +2/+2 from Smuggler's Crate.   NaN     NaN     NaN
# 15     <b>Battlecry:</b> Restore 4 Health to your hero.   6.0     5.0     4.0
# 16          Turn each minion in play into a 1/1 Murloc.   0.0     NaN     NaN
# 17    While this is in your hand, take 2 damage at t...   2.0     NaN     NaN
# 18    <b>Deathrattle:</b> Shuffle this minion into y...   1.0     1.0     1.0
# 19    <b>Battlecry:</b> The next Dragon you play cos...   5.0     5.0     5.0
# 20             Summon three, four, or five 1/1 Murlocs.   4.0     NaN     NaN
# 21                                                 None   4.0     7.0     7.0
# 22                                                 None   NaN     NaN    30.0
# 23    Transform your minions into random minions tha...   1.0     NaN     NaN
# 24                                                 None   NaN     NaN    30.0
# 25    <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0     2.0     2.0
# 26                    Deal $5 damage to all characters.   6.0     NaN     NaN
# 27    <b>Hero Power</b>\nDeal $2 damage to the enemy...   2.0     NaN     NaN
# 28                          Your minions cost (3) more.   5.0     7.0     6.0
# 29    <b>Battlecry:</b> If you're holding a Dragon, ...   2.0     1.0     3.0
# ...                                                 ...   ...     ...     ...
# 1049  <b>Battlecry:</b> If you're holding a Dragon, ...   4.0     2.0     6.0
# 1050                                               None   NaN     NaN    30.0
# 1051  <b>Deathrattle:</b> Shuffle this minion into y...   7.0     9.0     7.0
# 1052           Your healing effects are dealing damage.   NaN     NaN     NaN
# 1053                                               None   4.0     2.0     7.0
# 1054                <b>Battlecry: Discover</b> a spell.   5.0     6.0     3.0
# 1055                                             +2/+2.   NaN     NaN     NaN
# 1056  [x]<b>Taunt</b>\n<b>Battlecry:</b> Give your C...   2.0     1.0     4.0
# 1057  <b>Secret:</b> When an enemy minion attacks, r...   2.0     NaN     NaN
# 1058  <b>Taunt</b>\nCan't be targeted by spells or H...   9.0     5.0     9.0
# 1059                   <b>Deathrattle:</b> Draw a card.   4.0     4.0     2.0
# 1060  <b>Deathrattle:</b> Summon a Spectral Trainee ...   1.0     2.0     2.0
# 1061                                               None   2.0     2.0     2.0
# 1062                                               None   NaN     NaN    30.0
# 1063  Shuffle an enemy minion into your opponent's d...   6.0     NaN     NaN
# 1064  <b>Battlecry:</b> Destroy your opponent's weap...   5.0     5.0     4.0
# 1065  <b>Charge</b>. <b>Battlecry:</b> Summon two 1/...   5.0     6.0     2.0
# 1066  <b>Hero Power</b>\nGive your lowest attack min...   2.0     NaN     NaN
# 1067                                               None   4.0     2.0     6.0
# 1068                                       <b>Taunt</b>   4.0     5.0     4.0
# 1069  Shuffle 10 Unstable Portals into each player's...   0.0     NaN     NaN
# 1070                +3 Attack and <b>Divine Shield</b>.   NaN     NaN     NaN
# 1071    Deal $5 damage. Restore #5 Health to your hero.   4.0     NaN     NaN
# 1072           Whenever you discard a card, gain +1/+1.   2.0     3.0     2.0
# 1073                            Your turns are shorter.   NaN     NaN     NaN
# 1074                                               None   0.0     1.0     1.0
# 1075  <b>Battlecry:</b> If your hand is empty, gain ...   4.0     4.0     4.0
# 1076                                             +2/+2.   NaN     NaN     NaN
# 1077                                           +10/+10.   NaN     NaN     NaN
# 1078                                       <b>Taunt</b>   2.0     2.0     2.0
#
#          rarity  collectible  \
# 0          None          NaN
# 1          None          NaN
# 2        COMMON          NaN
# 3     LEGENDARY          1.0
# 4        COMMON          1.0
# 5     LEGENDARY          NaN
# 6          None          NaN
# 7          None          NaN
# 8          None          NaN
# 9          None          NaN
# 10    LEGENDARY          1.0
# 11         None          NaN
# 12         None          NaN
# 13         None          NaN
# 14         None          NaN
# 15       COMMON          1.0
# 16         None          NaN
# 17         None          NaN
# 18         EPIC          1.0
# 19         RARE          1.0
# 20         None          NaN
# 21         None          NaN
# 22         None          NaN
# 23         RARE          1.0
# 24         None          NaN
# 25       COMMON          1.0
# 26         RARE          1.0
# 27         FREE          NaN
# 28       COMMON          1.0
# 29       COMMON          1.0
# ...         ...          ...
# 1049       EPIC          1.0
# 1050       None          NaN
# 1051  LEGENDARY          1.0
# 1052       None          NaN
# 1053       FREE          1.0
# 1054     COMMON          1.0
# 1055       None          NaN
# 1056     COMMON          1.0
# 1057     COMMON          1.0
# 1058  LEGENDARY          1.0
# 1059     COMMON          1.0
# 1060       None          NaN
# 1061       None          NaN
# 1062       None          NaN
# 1063       RARE          1.0
# 1064  LEGENDARY          1.0
# 1065  LEGENDARY          1.0
# 1066       None          NaN
# 1067       None          NaN
# 1068     COMMON          1.0
# 1069       None          NaN
# 1070       None          NaN
# 1071       None          NaN
# 1072       RARE          1.0
# 1073       None          NaN
# 1074       None          NaN
# 1075       RARE          1.0
# 1076       None          NaN
# 1077       None          NaN
# 1078     COMMON          1.0
#
#                                                  flavor        race  \
# 0                                                  None        None
# 1                                                  None        None
# 2                                                  None       BEAST
# 3     It's like putting racing stripes and a giant s...        None
# 4     Rejected names: Forty-Foot Faceless, Big ol' N...        None
# 5                                                  None        None
# 6                                                  None        None
# 7                                                  None        None
# 8                                                  None        None
# 9                                                  None        None
# 10               HATES being called "the wonder twins".        None
# 11                                                 None        None
# 12                                                 None        None
# 13                                                 None        None
# 14                                                 None        None
# 15    If she threatens to "moon" you, it's not what ...        None
# 16                                                 None        None
# 17                                                 None        None
# 18    He's the reason the First Bank of Gadgetzan ha...       BEAST
# 19    Everybody wants someone to snuggle with. Even ...      DRAGON
# 20                                                 None        None
# 21                                                 None      DRAGON
# 22                                                 None        None
# 23    So you say you want an evolution. Well, you kn...        None
# 24                                                 None        None
# 25    It's adorable! AND OH MY GOODNESS WHY IS IT EA...  MECHANICAL
# 26    Kazakus has a squad of imps bottling Felfire r...        None
# 27                                                 None        None
# 28               No Job is too big.  No fee is too big.        None
# 29    She can tell you all about the history of peop...        None
# ...                                                 ...         ...
# 1049  A result of magical experiments carried out by...      DRAGON
# 1050                                               None        None
# 1051  When Malorne isn't mauling hordes of demons, h...       BEAST
# 1052                                               None        None
# 1053  His dreams of flying and breathing fire like h...       BEAST
# 1054           Despite the name, he's a solid conjurer.        None
# 1055                                               None        None
# 1056  "Ok C'Thun, repeat after me: 'Your mother was ...        None
# 1057  "Dang, that's cold." - appropriate response to...        None
# 1058  Don't tell Soggoth, but in the future he gets ...        None
# 1059          Roll ‘greed’ OR THIS COULD HAPPEN TO YOU.        None
# 1060                                               None        None
# 1061                                               None        None
# 1062                                               None        None
# 1063  Druidic recycling involves putting plastics in...        None
# 1064           “That belongs in the Hall of Explorers!”        None
# 1065                     At least he has Angry Chicken.        None
# 1066                                               None        None
# 1067                                               None        None
# 1068  To be honest, heckling is not the most effecti...        None
# 1069                                               None        None
# 1070                                               None        None
# 1071                                               None        None
# 1072   "No, no, no. I asked for a tiny JESTER of evil."       DEMON
# 1073                                               None        None
# 1074                                               None        None
# 1075  It takes a special kind of hunter to venture d...       BEAST
# 1076                                               None        None
# 1077                                               None        None
# 1078  Grunting is what his father did and his father...        None
#
#                                             how_to_earn  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19    Unlocked in Blackrock Spire, in the Blackrock ...
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29     Unlocked in the Spire, in One Night in Karazhan.
# ...                                                 ...
# 1049                                               None
# 1050                                               None
# 1051                                               None
# 1052                                               None
# 1053                                               None
# 1054  Unlocked in Uldaman, in the League of Explorer...
# 1055                                               None
# 1056                                               None
# 1057                                               None
# 1058                                               None
# 1059                                               None
# 1060                                               None
# 1061                                               None
# 1062                                               None
# 1063                                               None
# 1064                                               None
# 1065                                               None
# 1066                                               None
# 1067                                               None
# 1068                                               None
# 1069                                               None
# 1070                                               None
# 1071                                               None
# 1072                                               None
# 1073                                               None
# 1074                                               None
# 1075  Unlocked in Blackrock Spire, in the Blackrock ...
# 1076                                               None
# 1077                                               None
# 1078                                               None
#
#                                      how_to_earn_golden targeting_arrow_text  \
# 0                                                  None                 None
# 1                                                  None                 None
# 2                                                  None                 None
# 3                                                  None                 None
# 4                                                  None                 None
# 5                                                  None                 None
# 6                                                  None                 None
# 7                                                  None                 None
# 8                                                  None                 None
# 9                                                  None                 None
# 10                                                 None                 None
# 11                                                 None                 None
# 12                                                 None                 None
# 13                                                 None                 None
# 14                                                 None                 None
# 15                                                 None                 None
# 16                                                 None                 None
# 17                                                 None                 None
# 18                                                 None                 None
# 19    Crafting unlocked in Blackrock Spire, in the B...                 None
# 20                                                 None                 None
# 21                                                 None                 None
# 22                                                 None                 None
# 23                                                 None                 None
# 24                                                 None                 None
# 25                                                 None                 None
# 26                                                 None                 None
# 27                                                 None                 None
# 28                                                 None                 None
# 29    Crafting unlocked in the Spire, in One Night i...                 None
# ...                                                 ...                  ...
# 1049                                               None                 None
# 1050                                               None                 None
# 1051                                               None                 None
# 1052                                               None                 None
# 1053                        Unlocked at Druid Level 51.                 None
# 1054  Crafting unlocked in Uldaman, in the League of...                 None
# 1055                                               None                 None
# 1056                                               None                 None
# 1057                                               None                 None
# 1058                                               None                 None
# 1059                                               None                 None
# 1060                                               None                 None
# 1061                                               None                 None
# 1062                                               None                 None
# 1063                                               None                 None
# 1064                                               None                 None
# 1065                                               None                 None
# 1066                                               None                 None
# 1067                                               None                 None
# 1068                                               None                 None
# 1069                                               None                 None
# 1070                                               None                 None
# 1071                                               None                 None
# 1072                                               None                 None
# 1073                                               None                 None
# 1074                                               None                 None
# 1075  Crafting unlocked in Blackrock Spire, in the B...                 None
# 1076                                               None                 None
# 1077                                               None                 None
# 1078                       Unlocked at Shaman Level 57.                 None
#
#        faction  durability       card_id_right             mechanic
# 0         None         NaN              AT_132            BATTLECRY
# 1         None         NaN            GVG_011a  TAG_ONE_TURN_EFFECT
# 2         None         NaN             EX1_583            BATTLECRY
# 3         None         NaN            LOE_007t            EVIL_GLOW
# 4         None         NaN            LOE_007t   ImmuneToSpellpower
# 5         None         NaN             CFM_095          DEATHRATTLE
# 6         None         NaN             BRM_018            BATTLECRY
# 7         None         NaN             GVG_030           CHOOSE_ONE
# 8         None         NaN             GVG_030                TAUNT
# 9         None         NaN             CS2_227                 AURA
# 10        None         NaN             KAR_062            BATTLECRY
# 11        None         NaN         CFM_712_t17           JADE_GOLEM
# 12        None         NaN            BRM_011t  TAG_ONE_TURN_EFFECT
# 13        None         NaN           BRMA10_3H         AI_MUST_PLAY
# 14        None         NaN            KAR_710m                TAUNT
# 15        None         NaN            EX1_295o  TAG_ONE_TURN_EFFECT
# 16        None         NaN              OG_158          DEATHRATTLE
# 17        None         NaN            LOE_110t              TOPDECK
# 18        None         NaN            LOE_110t   ImmuneToSpellpower
# 19        None         NaN           BRMA13_4H         AI_MUST_PLAY
# 20        None         NaN            EX1_145o  TAG_ONE_TURN_EFFECT
# 21        None         NaN           LOEA09_2e  TAG_ONE_TURN_EFFECT
# 22        None         NaN            EX1_570e  TAG_ONE_TURN_EFFECT
# 23        None         NaN             GVG_069            BATTLECRY
# 24        None         NaN             hexfrog                TAUNT
# 25        None         NaN              OG_145        DIVINE_SHIELD
# 26        None         NaN              OG_145                TAUNT
# 27        None         NaN              AT_090              INSPIRE
# 28       HORDE         NaN              AT_060               SECRET
# 29        None         NaN  TB_MechWar_Minion1                TAUNT
# ...        ...         ...                 ...                  ...
# 1049      None         NaN             EX1_284            BATTLECRY
# 1050      None         NaN             LOE_038                 AURA
# 1051      None         NaN              AT_083              INSPIRE
# 1052      None         NaN    TB_CoOpv3_BOSS2e              ENRAGED
# 1053      None         NaN             GVG_009            BATTLECRY
# 1054      None         NaN             CFM_338            BATTLECRY
# 1055      None         NaN             GVG_097            BATTLECRY
# 1056      None         NaN             GVG_097                TAUNT
# 1057      None         NaN             CFM_852            BATTLECRY
# 1058      None         NaN             LOE_020            BATTLECRY
# 1059      None         NaN             CFM_781              STEALTH
# 1060      None         NaN             GVG_090            BATTLECRY
# 1061      None         NaN             GVG_120            BATTLECRY
# 1062      None         NaN            EX1_055o  TAG_ONE_TURN_EFFECT
# 1063      None         NaN             CFM_321            BATTLECRY
# 1064      None         NaN             EX1_082            BATTLECRY
# 1065  ALLIANCE         NaN             FP1_017                 AURA
# 1066      None         NaN             FP1_001          DEATHRATTLE
# 1067      None         NaN              AT_089              INSPIRE
# 1068      None         NaN             CFM_646          DEATHRATTLE
# 1069      None         NaN              AT_084            BATTLECRY
# 1070      None         NaN             OG_044a               CHARGE
# 1071      None         NaN             OG_044a                TAUNT
# 1072      None         NaN           LOEA09_3d         AI_MUST_PLAY
# 1073      None         NaN            BRMA13_4         AI_MUST_PLAY
# 1074      None         NaN             EX1_009              ENRAGED
# 1075      None         NaN            BRMA10_3         AI_MUST_PLAY
# 1076      None         NaN            NAX3_02H         AI_MUST_PLAY
# 1077      None         NaN             AT_083e  TAG_ONE_TURN_EFFECT
# 1078      None         NaN             CS2_031               FREEZE
#
# [1079 rows x 20 columns]

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads we displayed earlier.  Notice how it this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, conntains only 1079 rows.  Why?
#
# Write your answer below this line:
# ________________________________________________________________________________
#
#
# ### Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = cards_with_mechanics_df.join(play_requirements_df,how='left',lsuffix='_left', rsuffix='_right')
left_join_df
# Out:
#                     card_id_left player_class         type  \
# 0                     KARA_00_07         MAGE        SPELL
# 1                      NEW1_008a        DRUID        SPELL
# 2                      BRM_010t2        DRUID       MINION
# 3                         AT_132      NEUTRAL       MINION
# 4                         OG_141      NEUTRAL       MINION
# 5                        CRED_17      NEUTRAL       MINION
# 6                        OG_337e      NEUTRAL  ENCHANTMENT
# 7                      BRMA08_1H      NEUTRAL         HERO
# 8                       GVG_011a      NEUTRAL  ENCHANTMENT
# 9                    NAX8_02H_TB      NEUTRAL   HERO_POWER
# 10                        AT_131      NEUTRAL       MINION
# 11                      CS2_122e      NEUTRAL  ENCHANTMENT
# 12                   LOEA05_02ha      NEUTRAL   HERO_POWER
# 13             CS2_102_H1_AT_132      WARRIOR   HERO_POWER
# 14                      CFM_334e      NEUTRAL  ENCHANTMENT
# 15                       EX1_583      NEUTRAL       MINION
# 16        TB_PickYourFate_11rand      NEUTRAL        SPELL
# 17                      LOE_007t      WARLOCK        SPELL
# 18                       CFM_095      NEUTRAL       MINION
# 19                       BRM_018      PALADIN       MINION
# 20                      PRO_001a      NEUTRAL        SPELL
# 21                     BRMA10_5H      NEUTRAL       MINION
# 22                      BRMA11_1      NEUTRAL         HERO
# 23                        OG_027       SHAMAN        SPELL
# 24                       NAX1_01      NEUTRAL         HERO
# 25                       GVG_030        DRUID       MINION
# 26                       CFM_094      WARLOCK        SPELL
# 27                   DS1h_292_H1       HUNTER   HERO_POWER
# 28                       CS2_227      NEUTRAL       MINION
# 29                       KAR_062      NEUTRAL       MINION
# ...                          ...          ...          ...
# 1049                      AT_017      NEUTRAL       MINION
# 1050                    LOEA12_1      NEUTRAL         HERO
# 1051                     GVG_035        DRUID       MINION
# 1052                     OG_104e      NEUTRAL  ENCHANTMENT
# 1053                     CS2_119      NEUTRAL       MINION
# 1054                     LOE_003         MAGE       MINION
# 1055                    LOE_113e      NEUTRAL  ENCHANTMENT
# 1056                      OG_284      NEUTRAL       MINION
# 1057                     EX1_611       HUNTER        SPELL
# 1058                      OG_340      NEUTRAL       MINION
# 1059                      OG_323      NEUTRAL       MINION
# 1060                     NAX8_03      NEUTRAL       MINION
# 1061                   LOE_089t3      NEUTRAL       MINION
# 1062                    TU4e_001       HUNTER         HERO
# 1063                     GVG_031        DRUID        SPELL
# 1064                     EX1_558      NEUTRAL       MINION
# 1065                     EX1_116      NEUTRAL       MINION
# 1066  TB_MechWar_Boss1_HeroPower      NEUTRAL   HERO_POWER
# 1067                   LOEA07_09      NEUTRAL       MINION
# 1068                      AT_114      NEUTRAL       MINION
# 1069           TB_PickYourFate_6      NEUTRAL        SPELL
# 1070                    AT_074e2      PALADIN  ENCHANTMENT
# 1071            KARA_09_07heroic      NEUTRAL        SPELL
# 1072                      AT_021      WARLOCK       MINION
# 1073                    GAME_004      NEUTRAL  ENCHANTMENT
# 1074              AT_132_SHAMANb       SHAMAN       MINION
# 1075                     BRM_014       HUNTER       MINION
# 1076                    CFM_617e      NEUTRAL  ENCHANTMENT
# 1077                   LOEA16_3e      NEUTRAL  ENCHANTMENT
# 1078                     CS2_121      NEUTRAL       MINION
#
#                          name         set  \
# 0               Astral Portal        KARA
# 1           Ancient Teachings     EXPERT1
# 2          Druid of the Flame         BRM
# 3          Justicar Trueheart         TGT
# 4           Faceless Behemoth          OG
# 5                   Rob Pardo     CREDITS
# 6          Eve of Destruction          OG
# 7          General Drakkisath         BRM
# 8                  Shrink Ray         GVG
# 9                     Harvest          TB
# 10             Eydis Darkbane         TGT
# 11                   Enhanced        CORE
# 12        Trogg Hate Minions!         LOE
# 13                   Tank Up!  HERO_SKINS
# 14                  Smuggling       GANGS
# 15         Priestess of Elune     EXPERT1
# 16         Dire Fate: Murlocs          TB
# 17                    Cursed!         LOE
# 18            Weasel Tunneler       GANGS
# 19             Dragon Consort         BRM
# 20                I Am Murloc       PROMO
# 21            Chromatic Drake         BRM
# 22    Vaelastrasz the Corrupt         BRM
# 23                     Evolve          OG
# 24                Anub'Rekhan        NAXX
# 25          Anodized Robo Cub         GVG
# 26             Felfire Potion       GANGS
# 27                Steady Shot  HERO_SKINS
# 28      Venture Co. Mercenary     EXPERT1
# 29      Netherspite Historian        KARA
# ...                       ...         ...
# 1049        Twilight Guardian         TGT
# 1050             Lady Naz'jar         LOE
# 1051                  Malorne         GVG
# 1052     Embracing the Shadow          OG
# 1053            Oasis Snapjaw        CORE
# 1054        Ethereal Conjurer         LOE
# 1055      Mrglllraawrrrglrur!         LOE
# 1056       Twilight Geomancer          OG
# 1057            Freezing Trap     EXPERT1
# 1058    Soggoth the Slitherer          OG
# 1059         Polluted Hoarder          OG
# 1060      Unrelenting Trainee        NAXX
# 1061             Grumbly Runt         LOE
# 1062        Illidan Stormrage    MISSIONS
# 1063                  Recycle         GVG
# 1064           Harrison Jones     EXPERT1
# 1065           Leeroy Jenkins     EXPERT1
# 1066     Hello! Hello! Hello!          TB
# 1067            Chasing Trogg         LOE
# 1068             Evil Heckler         TGT
# 1069            Fate: Portals          TB
# 1070        Seal of Champions         TGT
# 1071               Steal Life        KARA
# 1072      Tiny Knight of Evil         TGT
# 1073                      AFK        CORE
# 1074            Searing Totem         TGT
# 1075               Core Rager         BRM
# 1076        Visions of Hypnos       GANGS
# 1077         Lantern of Power         LOE
# 1078          Frostwolf Grunt        CORE
#
#                                                    text  cost  attack  health  \
# 0              Summon a random <b>Legendary</b> minion.   1.0     NaN     NaN
# 1                                          Draw a card.   0.0     NaN     NaN
# 2                                                  None   3.0     2.0     5.0
# 3     <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0     3.0
# 4                                                  None  10.0    10.0    10.0
# 5     You can't start a game without this minion in ...   9.0     9.0     9.0
# 6                                      Stats increased.   NaN     NaN     NaN
# 7                                                  None   NaN     NaN    50.0
# 8                                  -2 Attack this turn.   NaN     NaN     NaN
# 9     <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...   2.0     NaN     NaN
# 10    Whenever <b>you</b> target this minion with a ...   3.0     3.0     4.0
# 11       Raid Leader is granting this minion +1 Attack.   NaN     NaN     NaN
# 12    <b>Passive Hero Power</b>\n Enemy minions cost...   0.0     NaN     NaN
# 13                     <b>Hero Power</b>\nGain 4 Armor.   2.0     NaN     NaN
# 14                         +2/+2 from Smuggler's Crate.   NaN     NaN     NaN
# 15     <b>Battlecry:</b> Restore 4 Health to your hero.   6.0     5.0     4.0
# 16          Turn each minion in play into a 1/1 Murloc.   0.0     NaN     NaN
# 17    While this is in your hand, take 2 damage at t...   2.0     NaN     NaN
# 18    <b>Deathrattle:</b> Shuffle this minion into y...   1.0     1.0     1.0
# 19    <b>Battlecry:</b> The next Dragon you play cos...   5.0     5.0     5.0
# 20             Summon three, four, or five 1/1 Murlocs.   4.0     NaN     NaN
# 21                                                 None   4.0     7.0     7.0
# 22                                                 None   NaN     NaN    30.0
# 23    Transform your minions into random minions tha...   1.0     NaN     NaN
# 24                                                 None   NaN     NaN    30.0
# 25    <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0     2.0     2.0
# 26                    Deal $5 damage to all characters.   6.0     NaN     NaN
# 27    <b>Hero Power</b>\nDeal $2 damage to the enemy...   2.0     NaN     NaN
# 28                          Your minions cost (3) more.   5.0     7.0     6.0
# 29    <b>Battlecry:</b> If you're holding a Dragon, ...   2.0     1.0     3.0
# ...                                                 ...   ...     ...     ...
# 1049  <b>Battlecry:</b> If you're holding a Dragon, ...   4.0     2.0     6.0
# 1050                                               None   NaN     NaN    30.0
# 1051  <b>Deathrattle:</b> Shuffle this minion into y...   7.0     9.0     7.0
# 1052           Your healing effects are dealing damage.   NaN     NaN     NaN
# 1053                                               None   4.0     2.0     7.0
# 1054                <b>Battlecry: Discover</b> a spell.   5.0     6.0     3.0
# 1055                                             +2/+2.   NaN     NaN     NaN
# 1056  [x]<b>Taunt</b>\n<b>Battlecry:</b> Give your C...   2.0     1.0     4.0
# 1057  <b>Secret:</b> When an enemy minion attacks, r...   2.0     NaN     NaN
# 1058  <b>Taunt</b>\nCan't be targeted by spells or H...   9.0     5.0     9.0
# 1059                   <b>Deathrattle:</b> Draw a card.   4.0     4.0     2.0
# 1060  <b>Deathrattle:</b> Summon a Spectral Trainee ...   1.0     2.0     2.0
# 1061                                               None   2.0     2.0     2.0
# 1062                                               None   NaN     NaN    30.0
# 1063  Shuffle an enemy minion into your opponent's d...   6.0     NaN     NaN
# 1064  <b>Battlecry:</b> Destroy your opponent's weap...   5.0     5.0     4.0
# 1065  <b>Charge</b>. <b>Battlecry:</b> Summon two 1/...   5.0     6.0     2.0
# 1066  <b>Hero Power</b>\nGive your lowest attack min...   2.0     NaN     NaN
# 1067                                               None   4.0     2.0     6.0
# 1068                                       <b>Taunt</b>   4.0     5.0     4.0
# 1069  Shuffle 10 Unstable Portals into each player's...   0.0     NaN     NaN
# 1070                +3 Attack and <b>Divine Shield</b>.   NaN     NaN     NaN
# 1071    Deal $5 damage. Restore #5 Health to your hero.   4.0     NaN     NaN
# 1072           Whenever you discard a card, gain +1/+1.   2.0     3.0     2.0
# 1073                            Your turns are shorter.   NaN     NaN     NaN
# 1074                                               None   0.0     1.0     1.0
# 1075  <b>Battlecry:</b> If your hand is empty, gain ...   4.0     4.0     4.0
# 1076                                             +2/+2.   NaN     NaN     NaN
# 1077                                           +10/+10.   NaN     NaN     NaN
# 1078                                       <b>Taunt</b>   2.0     2.0     2.0
#
#          rarity  ...                                         how_to_earn  \
# 0          None  ...                                                None
# 1          None  ...                                                None
# 2        COMMON  ...                                                None
# 3     LEGENDARY  ...                                                None
# 4        COMMON  ...                                                None
# 5     LEGENDARY  ...                                                None
# 6          None  ...                                                None
# 7          None  ...                                                None
# 8          None  ...                                                None
# 9          None  ...                                                None
# 10    LEGENDARY  ...                                                None
# 11         None  ...                                                None
# 12         None  ...                                                None
# 13         None  ...                                                None
# 14         None  ...                                                None
# 15       COMMON  ...                                                None
# 16         None  ...                                                None
# 17         None  ...                                                None
# 18         EPIC  ...                                                None
# 19         RARE  ...   Unlocked in Blackrock Spire, in the Blackrock ...
# 20         None  ...                                                None
# 21         None  ...                                                None
# 22         None  ...                                                None
# 23         RARE  ...                                                None
# 24         None  ...                                                None
# 25       COMMON  ...                                                None
# 26         RARE  ...                                                None
# 27         FREE  ...                                                None
# 28       COMMON  ...                                                None
# 29       COMMON  ...    Unlocked in the Spire, in One Night in Karazhan.
# ...         ...  ...                                                 ...
# 1049       EPIC  ...                                                None
# 1050       None  ...                                                None
# 1051  LEGENDARY  ...                                                None
# 1052       None  ...                                                None
# 1053       FREE  ...                                                None
# 1054     COMMON  ...   Unlocked in Uldaman, in the League of Explorer...
# 1055       None  ...                                                None
# 1056     COMMON  ...                                                None
# 1057     COMMON  ...                                                None
# 1058  LEGENDARY  ...                                                None
# 1059     COMMON  ...                                                None
# 1060       None  ...                                                None
# 1061       None  ...                                                None
# 1062       None  ...                                                None
# 1063       RARE  ...                                                None
# 1064  LEGENDARY  ...                                                None
# 1065  LEGENDARY  ...                                                None
# 1066       None  ...                                                None
# 1067       None  ...                                                None
# 1068     COMMON  ...                                                None
# 1069       None  ...                                                None
# 1070       None  ...                                                None
# 1071       None  ...                                                None
# 1072       RARE  ...                                                None
# 1073       None  ...                                                None
# 1074       None  ...                                                None
# 1075       RARE  ...   Unlocked in Blackrock Spire, in the Blackrock ...
# 1076       None  ...                                                None
# 1077       None  ...                                                None
# 1078     COMMON  ...                                                None
#
#                                      how_to_earn_golden targeting_arrow_text  \
# 0                                                  None                 None
# 1                                                  None                 None
# 2                                                  None                 None
# 3                                                  None                 None
# 4                                                  None                 None
# 5                                                  None                 None
# 6                                                  None                 None
# 7                                                  None                 None
# 8                                                  None                 None
# 9                                                  None                 None
# 10                                                 None                 None
# 11                                                 None                 None
# 12                                                 None                 None
# 13                                                 None                 None
# 14                                                 None                 None
# 15                                                 None                 None
# 16                                                 None                 None
# 17                                                 None                 None
# 18                                                 None                 None
# 19    Crafting unlocked in Blackrock Spire, in the B...                 None
# 20                                                 None                 None
# 21                                                 None                 None
# 22                                                 None                 None
# 23                                                 None                 None
# 24                                                 None                 None
# 25                                                 None                 None
# 26                                                 None                 None
# 27                                                 None                 None
# 28                                                 None                 None
# 29    Crafting unlocked in the Spire, in One Night i...                 None
# ...                                                 ...                  ...
# 1049                                               None                 None
# 1050                                               None                 None
# 1051                                               None                 None
# 1052                                               None                 None
# 1053                        Unlocked at Druid Level 51.                 None
# 1054  Crafting unlocked in Uldaman, in the League of...                 None
# 1055                                               None                 None
# 1056                                               None                 None
# 1057                                               None                 None
# 1058                                               None                 None
# 1059                                               None                 None
# 1060                                               None                 None
# 1061                                               None                 None
# 1062                                               None                 None
# 1063                                               None                 None
# 1064                                               None                 None
# 1065                                               None                 None
# 1066                                               None                 None
# 1067                                               None                 None
# 1068                                               None                 None
# 1069                                               None                 None
# 1070                                               None                 None
# 1071                                               None                 None
# 1072                                               None                 None
# 1073                                               None                 None
# 1074                                               None                 None
# 1075  Crafting unlocked in Blackrock Spire, in the B...                 None
# 1076                                               None                 None
# 1077                                               None                 None
# 1078                       Unlocked at Shaman Level 57.                 None
#
#        faction durability       card_id_right             mechanic  \
# 0         None        NaN              AT_132            BATTLECRY
# 1         None        NaN            GVG_011a  TAG_ONE_TURN_EFFECT
# 2         None        NaN             EX1_583            BATTLECRY
# 3         None        NaN            LOE_007t            EVIL_GLOW
# 4         None        NaN            LOE_007t   ImmuneToSpellpower
# 5         None        NaN             CFM_095          DEATHRATTLE
# 6         None        NaN             BRM_018            BATTLECRY
# 7         None        NaN             GVG_030           CHOOSE_ONE
# 8         None        NaN             GVG_030                TAUNT
# 9         None        NaN             CS2_227                 AURA
# 10        None        NaN             KAR_062            BATTLECRY
# 11        None        NaN         CFM_712_t17           JADE_GOLEM
# 12        None        NaN            BRM_011t  TAG_ONE_TURN_EFFECT
# 13        None        NaN           BRMA10_3H         AI_MUST_PLAY
# 14        None        NaN            KAR_710m                TAUNT
# 15        None        NaN            EX1_295o  TAG_ONE_TURN_EFFECT
# 16        None        NaN              OG_158          DEATHRATTLE
# 17        None        NaN            LOE_110t              TOPDECK
# 18        None        NaN            LOE_110t   ImmuneToSpellpower
# 19        None        NaN           BRMA13_4H         AI_MUST_PLAY
# 20        None        NaN            EX1_145o  TAG_ONE_TURN_EFFECT
# 21        None        NaN           LOEA09_2e  TAG_ONE_TURN_EFFECT
# 22        None        NaN            EX1_570e  TAG_ONE_TURN_EFFECT
# 23        None        NaN             GVG_069            BATTLECRY
# 24        None        NaN             hexfrog                TAUNT
# 25        None        NaN              OG_145        DIVINE_SHIELD
# 26        None        NaN              OG_145                TAUNT
# 27        None        NaN              AT_090              INSPIRE
# 28       HORDE        NaN              AT_060               SECRET
# 29        None        NaN  TB_MechWar_Minion1                TAUNT
# ...        ...        ...                 ...                  ...
# 1049      None        NaN             EX1_284            BATTLECRY
# 1050      None        NaN             LOE_038                 AURA
# 1051      None        NaN              AT_083              INSPIRE
# 1052      None        NaN    TB_CoOpv3_BOSS2e              ENRAGED
# 1053      None        NaN             GVG_009            BATTLECRY
# 1054      None        NaN             CFM_338            BATTLECRY
# 1055      None        NaN             GVG_097            BATTLECRY
# 1056      None        NaN             GVG_097                TAUNT
# 1057      None        NaN             CFM_852            BATTLECRY
# 1058      None        NaN             LOE_020            BATTLECRY
# 1059      None        NaN             CFM_781              STEALTH
# 1060      None        NaN             GVG_090            BATTLECRY
# 1061      None        NaN             GVG_120            BATTLECRY
# 1062      None        NaN            EX1_055o  TAG_ONE_TURN_EFFECT
# 1063      None        NaN             CFM_321            BATTLECRY
# 1064      None        NaN             EX1_082            BATTLECRY
# 1065  ALLIANCE        NaN             FP1_017                 AURA
# 1066      None        NaN             FP1_001          DEATHRATTLE
# 1067      None        NaN              AT_089              INSPIRE
# 1068      None        NaN             CFM_646          DEATHRATTLE
# 1069      None        NaN              AT_084            BATTLECRY
# 1070      None        NaN             OG_044a               CHARGE
# 1071      None        NaN             OG_044a                TAUNT
# 1072      None        NaN           LOEA09_3d         AI_MUST_PLAY
# 1073      None        NaN            BRMA13_4         AI_MUST_PLAY
# 1074      None        NaN             EX1_009              ENRAGED
# 1075      None        NaN            BRMA10_3         AI_MUST_PLAY
# 1076      None        NaN            NAX3_02H         AI_MUST_PLAY
# 1077      None        NaN             AT_083e  TAG_ONE_TURN_EFFECT
# 1078      None        NaN             CS2_031               FREEZE
#
#                 card_id           play_requirement value
# 0            KARA_00_07       REQ_NUM_MINION_SLOTS   1.0
# 1              PRO_001a       REQ_NUM_MINION_SLOTS   1.0
# 2               NAX1_01       REQ_NUM_MINION_SLOTS   1.0
# 3           DS1h_292_H1            REQ_STEADY_SHOT   0.0
# 4           DS1h_292_H1   REQ_MINION_OR_ENEMY_HERO   0.0
# 5               KAR_076         REQ_TARGET_TO_PLAY   0.0
# 6                AT_024         REQ_TARGET_TO_PLAY   0.0
# 7                AT_024       REQ_TARGET_WITH_RACE  15.0
# 8                AT_024          REQ_MINION_TARGET   0.0
# 9              BRMA06_2       REQ_NUM_MINION_SLOTS   1.0
# 10              NAX5_02  REQ_MINIMUM_ENEMY_MINIONS   1.0
# 11              OG_080c        REQ_FRIENDLY_TARGET   0.0
# 12              OG_080c         REQ_TARGET_TO_PLAY   0.0
# 13              OG_080c          REQ_MINION_TARGET   0.0
# 14              CS2_039         REQ_TARGET_TO_PLAY   0.0
# 15              CS2_039          REQ_MINION_TARGET   0.0
# 16    TB_KaraPortal_002          REQ_MINION_TARGET   0.0
# 17              CS2_094         REQ_TARGET_TO_PLAY   0.0
# 18      TB_SPT_DPromoHP          REQ_MINION_TARGET   0.0
# 19             BRMA15_3       REQ_NUM_MINION_SLOTS   1.0
# 20              CS2_141    REQ_TARGET_IF_AVAILABLE   0.0
# 21              CS2_141         REQ_NONSELF_TARGET   0.0
# 22              CS2_063         REQ_TARGET_TO_PLAY   0.0
# 23              CS2_063          REQ_MINION_TARGET   0.0
# 24              CS2_063           REQ_ENEMY_TARGET   0.0
# 25             GVG_055e        REQ_FRIENDLY_TARGET   0.0
# 26               TB_006         REQ_TARGET_TO_PLAY   0.0
# 27               TB_006          REQ_MINION_TARGET   0.0
# 28           CFM_621t21  REQ_MINIMUM_TOTAL_MINIONS   1.0
# 29           LOEA06_04h         REQ_TARGET_TO_PLAY   0.0
# ...                 ...                        ...   ...
# 1049                NaN                        NaN   NaN
# 1050                NaN                        NaN   NaN
# 1051                NaN                        NaN   NaN
# 1052                NaN                        NaN   NaN
# 1053                NaN                        NaN   NaN
# 1054                NaN                        NaN   NaN
# 1055                NaN                        NaN   NaN
# 1056                NaN                        NaN   NaN
# 1057                NaN                        NaN   NaN
# 1058                NaN                        NaN   NaN
# 1059                NaN                        NaN   NaN
# 1060                NaN                        NaN   NaN
# 1061                NaN                        NaN   NaN
# 1062                NaN                        NaN   NaN
# 1063                NaN                        NaN   NaN
# 1064                NaN                        NaN   NaN
# 1065                NaN                        NaN   NaN
# 1066                NaN                        NaN   NaN
# 1067                NaN                        NaN   NaN
# 1068                NaN                        NaN   NaN
# 1069                NaN                        NaN   NaN
# 1070                NaN                        NaN   NaN
# 1071                NaN                        NaN   NaN
# 1072                NaN                        NaN   NaN
# 1073                NaN                        NaN   NaN
# 1074                NaN                        NaN   NaN
# 1075                NaN                        NaN   NaN
# 1076                NaN                        NaN   NaN
# 1077                NaN                        NaN   NaN
# 1078                NaN                        NaN   NaN
#
# [1079 rows x 23 columns]

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if we were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# ________________________________________________________________________________
#
#
#
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = cards_df.join(entourages_df,how='outer',lsuffix='_left', rsuffix='_entourages')
outer_join_df
# Out:
#                        card_id_left player_class         type  \
# 0                        KARA_00_07         MAGE        SPELL
# 1                         NEW1_008a        DRUID        SPELL
# 2                         BRM_010t2        DRUID       MINION
# 3                            AT_132      NEUTRAL       MINION
# 4                            OG_141      NEUTRAL       MINION
# 5                           CRED_17      NEUTRAL       MINION
# 6                           OG_337e      NEUTRAL  ENCHANTMENT
# 7                         BRMA08_1H      NEUTRAL         HERO
# 8                          GVG_011a      NEUTRAL  ENCHANTMENT
# 9                       NAX8_02H_TB      NEUTRAL   HERO_POWER
# 10                           AT_131      NEUTRAL       MINION
# 11                         CS2_122e      NEUTRAL  ENCHANTMENT
# 12                      LOEA05_02ha      NEUTRAL   HERO_POWER
# 13                CS2_102_H1_AT_132      WARRIOR   HERO_POWER
# 14                         CFM_334e      NEUTRAL  ENCHANTMENT
# 15                          EX1_583      NEUTRAL       MINION
# 16           TB_PickYourFate_11rand      NEUTRAL        SPELL
# 17                         LOE_007t      WARLOCK        SPELL
# 18                          CFM_095      NEUTRAL       MINION
# 19                          BRM_018      PALADIN       MINION
# 20                         PRO_001a      NEUTRAL        SPELL
# 21                        BRMA10_5H      NEUTRAL       MINION
# 22                         BRMA11_1      NEUTRAL         HERO
# 23                           OG_027       SHAMAN        SPELL
# 24                          NAX1_01      NEUTRAL         HERO
# 25                          GVG_030        DRUID       MINION
# 26                          CFM_094      WARLOCK        SPELL
# 27                      DS1h_292_H1       HUNTER   HERO_POWER
# 28                          CS2_227      NEUTRAL       MINION
# 29                          KAR_062      NEUTRAL       MINION
# ...                             ...          ...          ...
# 2789                       LOEA12_2      NEUTRAL   HERO_POWER
# 2790                         AT_084      NEUTRAL       MINION
# 2791                     KARA_00_03         MAGE         HERO
# 2792                       BRMA16_3      NEUTRAL        SPELL
# 2793                        tt_010a         MAGE       MINION
# 2794                        EX1_559         MAGE       MINION
# 2795                        EX1_624       PRIEST        SPELL
# 2796                        OG_044a        DRUID       MINION
# 2797                         AT_044        DRUID        SPELL
# 2798                  AT_132_SHAMAN       SHAMAN   HERO_POWER
# 2799                     CFM_621t29      NEUTRAL        SPELL
# 2800                       EX1_355e      PALADIN  ENCHANTMENT
# 2801                      LOEA09_3d      NEUTRAL   HERO_POWER
# 2802                  TB_Coopv3_105      NEUTRAL       MINION
# 2803                       BRMA13_4      NEUTRAL   HERO_POWER
# 2804                       EX1_345t       PRIEST       MINION
# 2805                        EX1_009      NEUTRAL       MINION
# 2806                        CRED_32      NEUTRAL       MINION
# 2807                       FP1_030e      NEUTRAL  ENCHANTMENT
# 2808        TB_PickYourFate_10_Ench      NEUTRAL  ENCHANTMENT
# 2809             KARA_05_01hpheroic      NEUTRAL   HERO_POWER
# 2810                       BRMA10_3      NEUTRAL   HERO_POWER
# 2811  TB_PickYourFate_10_EnchMinion      NEUTRAL  ENCHANTMENT
# 2812                       NAX3_02H      NEUTRAL   HERO_POWER
# 2813                        AT_083e      NEUTRAL  ENCHANTMENT
# 2814                        AT_066e      WARRIOR  ENCHANTMENT
# 2815                        CS2_031         MAGE        SPELL
# 2816                        OG_195e      NEUTRAL  ENCHANTMENT
# 2817                       XXX_111e      NEUTRAL  ENCHANTMENT
# 2818                        NAX3_01      NEUTRAL         HERO
#
#                                         name         set  \
# 0                              Astral Portal        KARA
# 1                          Ancient Teachings     EXPERT1
# 2                         Druid of the Flame         BRM
# 3                         Justicar Trueheart         TGT
# 4                          Faceless Behemoth          OG
# 5                                  Rob Pardo     CREDITS
# 6                         Eve of Destruction          OG
# 7                         General Drakkisath         BRM
# 8                                 Shrink Ray         GVG
# 9                                    Harvest          TB
# 10                            Eydis Darkbane         TGT
# 11                                  Enhanced        CORE
# 12                       Trogg Hate Minions!         LOE
# 13                                  Tank Up!  HERO_SKINS
# 14                                 Smuggling       GANGS
# 15                        Priestess of Elune     EXPERT1
# 16                        Dire Fate: Murlocs          TB
# 17                                   Cursed!         LOE
# 18                           Weasel Tunneler       GANGS
# 19                            Dragon Consort         BRM
# 20                               I Am Murloc       PROMO
# 21                           Chromatic Drake         BRM
# 22                   Vaelastrasz the Corrupt         BRM
# 23                                    Evolve          OG
# 24                               Anub'Rekhan        NAXX
# 25                         Anodized Robo Cub         GVG
# 26                            Felfire Potion       GANGS
# 27                               Steady Shot  HERO_SKINS
# 28                     Venture Co. Mercenary     EXPERT1
# 29                     Netherspite Historian        KARA
# ...                                      ...         ...
# 2789                      Pearl of the Tides         LOE
# 2790                           Lance Carrier         TGT
# 2791                                  Medivh        KARA
# 2792                            Sonic Breath         BRM
# 2793                             Spellbender     EXPERT1
# 2794                      Archmage Antonidas     EXPERT1
# 2795                               Holy Fire     EXPERT1
# 2796                       Druid of the Claw     EXPERT1
# 2797                                   Mulch         TGT
# 2798                            Totemic Slam         TGT
# 2799                             Mystic Wool       GANGS
# 2800                        Blessed Champion     EXPERT1
# 2801                          Getting Hungry         LOE
# 2802                             Raid Healer          TB
# 2803                              Wild Magic         BRM
# 2804                       Shadow of Nothing     EXPERT1
# 2805                           Angry Chicken     EXPERT1
# 2806                            Jerry Mascho     CREDITS
# 2807                           Necrotic Aura        NAXX
# 2808                                    Fate          TB
# 2809                               Trembling        KARA
# 2810                             The Rookery         BRM
# 2811                                   Bonus          TB
# 2812                                Web Wrap        NAXX
# 2813                           Dragonhawkery         TGT
# 2814                     Forges of Orgrimmar         TGT
# 2815                               Ice Lance     EXPERT1
# 2816                                Enormous          OG
# 2817  All Charge, All Windfury, All The Time       CHEAT
# 2818                                 Maexxna        NAXX
#
#                                                    text  cost  attack  health  \
# 0              Summon a random <b>Legendary</b> minion.   1.0     NaN     NaN
# 1                                          Draw a card.   0.0     NaN     NaN
# 2                                                  None   3.0     2.0     5.0
# 3     <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0     3.0
# 4                                                  None  10.0    10.0    10.0
# 5     You can't start a game without this minion in ...   9.0     9.0     9.0
# 6                                      Stats increased.   NaN     NaN     NaN
# 7                                                  None   NaN     NaN    50.0
# 8                                  -2 Attack this turn.   NaN     NaN     NaN
# 9     <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...   2.0     NaN     NaN
# 10    Whenever <b>you</b> target this minion with a ...   3.0     3.0     4.0
# 11       Raid Leader is granting this minion +1 Attack.   NaN     NaN     NaN
# 12    <b>Passive Hero Power</b>\n Enemy minions cost...   0.0     NaN     NaN
# 13                     <b>Hero Power</b>\nGain 4 Armor.   2.0     NaN     NaN
# 14                         +2/+2 from Smuggler's Crate.   NaN     NaN     NaN
# 15     <b>Battlecry:</b> Restore 4 Health to your hero.   6.0     5.0     4.0
# 16          Turn each minion in play into a 1/1 Murloc.   0.0     NaN     NaN
# 17    While this is in your hand, take 2 damage at t...   2.0     NaN     NaN
# 18    <b>Deathrattle:</b> Shuffle this minion into y...   1.0     1.0     1.0
# 19    <b>Battlecry:</b> The next Dragon you play cos...   5.0     5.0     5.0
# 20             Summon three, four, or five 1/1 Murlocs.   4.0     NaN     NaN
# 21                                                 None   4.0     7.0     7.0
# 22                                                 None   NaN     NaN    30.0
# 23    Transform your minions into random minions tha...   1.0     NaN     NaN
# 24                                                 None   NaN     NaN    30.0
# 25    <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0     2.0     2.0
# 26                    Deal $5 damage to all characters.   6.0     NaN     NaN
# 27    <b>Hero Power</b>\nDeal $2 damage to the enemy...   2.0     NaN     NaN
# 28                          Your minions cost (3) more.   5.0     7.0     6.0
# 29    <b>Battlecry:</b> If you're holding a Dragon, ...   2.0     1.0     3.0
# ...                                                 ...   ...     ...     ...
# 2789  At the end of your turn, replace all minions w...   0.0     NaN     NaN
# 2790  <b>Battlecry:</b> Give a friendly minion +2 At...   2.0     1.0     2.0
# 2791                                               None   NaN     NaN    30.0
# 2792  Deal $3 damage to a minion. Give your weapon +...   4.0     NaN     NaN
# 2793                                               None   1.0     1.0     3.0
# 2794  Whenever you cast a spell, add a 'Fireball' sp...   7.0     5.0     7.0
# 2795    Deal $5 damage. Restore #5 Health to your hero.   6.0     NaN     NaN
# 2796                        <b>Charge</b>\n<b>Taunt</b>   5.0     4.0     6.0
# 2797  Destroy a minion.\nAdd a random minion to your...   3.0     NaN     NaN
# 2798  <b>Hero Power</b>\nSummon a Totem of your choice.   2.0     NaN     NaN
# 2799              Transform all minions into 1/1 Sheep.  10.0     NaN     NaN
# 2800             This minion's Attack has been doubled.   NaN     NaN     NaN
# 2801       <b>Hero Power</b>\nSummon a 5/1 Hungry Naga.   0.0     NaN     NaN
# 2802  Whenever your hero is healed, also heal your t...   4.0     0.0     7.0
# 2803  <b>Hero Power</b>\nPut a random spell from you...   1.0     NaN     NaN
# 2804   Mindgames whiffed! Your opponent had no minions!   0.0     0.0     1.0
# 2805                          <b>Enrage:</b> +5 Attack.   1.0     1.0     1.0
# 2806  At the start of your turn, deal 1 damage. If t...   2.0     3.0     2.0
# 2807               Your spells cost (5) more this turn.   NaN     NaN     NaN
# 2808                                               None   NaN     NaN     NaN
# 2809  <b>Passive Hero Power</b> Minions cost (1). En...   0.0     NaN     NaN
# 2810  <b>Hero Power</b>\nGive all Corrupted Eggs +1 ...   1.0     NaN     NaN
# 2811          Your <b>Battlecry</b> minions have +1/+1.   NaN     NaN     NaN
# 2812  <b>Hero Power</b>\nReturn 2 random enemy minio...   0.0     NaN     NaN
# 2813                         <b>Windfury</b> this turn.   NaN     NaN     NaN
# 2814                                  Increased Attack.   NaN     NaN     NaN
# 2815  <b>Freeze</b> a character. If it was already <...   1.0     NaN     NaN
# 2816                                             +2/+2.   NaN     NaN     NaN
# 2817  Your minions always have <b>Charge</b> and <b>...   NaN     NaN     NaN
# 2818                                               None   NaN     NaN    30.0
#
#          rarity  collectible  \
# 0          None          NaN
# 1          None          NaN
# 2        COMMON          NaN
# 3     LEGENDARY          1.0
# 4        COMMON          1.0
# 5     LEGENDARY          NaN
# 6          None          NaN
# 7          None          NaN
# 8          None          NaN
# 9          None          NaN
# 10    LEGENDARY          1.0
# 11         None          NaN
# 12         None          NaN
# 13         None          NaN
# 14         None          NaN
# 15       COMMON          1.0
# 16         None          NaN
# 17         None          NaN
# 18         EPIC          1.0
# 19         RARE          1.0
# 20         None          NaN
# 21         None          NaN
# 22         None          NaN
# 23         RARE          1.0
# 24         None          NaN
# 25       COMMON          1.0
# 26         RARE          1.0
# 27         FREE          NaN
# 28       COMMON          1.0
# 29       COMMON          1.0
# ...         ...          ...
# 2789       None          NaN
# 2790     COMMON          1.0
# 2791       None          NaN
# 2792       None          NaN
# 2793       EPIC          NaN
# 2794  LEGENDARY          1.0
# 2795       RARE          1.0
# 2796     COMMON          NaN
# 2797       EPIC          1.0
# 2798       None          NaN
# 2799       None          NaN
# 2800       None          NaN
# 2801       None          NaN
# 2802       None          NaN
# 2803       None          NaN
# 2804       EPIC          NaN
# 2805       RARE          1.0
# 2806  LEGENDARY          NaN
# 2807       None          NaN
# 2808       None          NaN
# 2809     COMMON          NaN
# 2810       None          NaN
# 2811       None          NaN
# 2812       None          NaN
# 2813       None          NaN
# 2814       None          NaN
# 2815     COMMON          1.0
# 2816       None          NaN
# 2817       None          NaN
# 2818       None          NaN
#
#                                                  flavor        race  \
# 0                                                  None        None
# 1                                                  None        None
# 2                                                  None       BEAST
# 3     It's like putting racing stripes and a giant s...        None
# 4     Rejected names: Forty-Foot Faceless, Big ol' N...        None
# 5                                                  None        None
# 6                                                  None        None
# 7                                                  None        None
# 8                                                  None        None
# 9                                                  None        None
# 10               HATES being called "the wonder twins".        None
# 11                                                 None        None
# 12                                                 None        None
# 13                                                 None        None
# 14                                                 None        None
# 15    If she threatens to "moon" you, it's not what ...        None
# 16                                                 None        None
# 17                                                 None        None
# 18    He's the reason the First Bank of Gadgetzan ha...       BEAST
# 19    Everybody wants someone to snuggle with. Even ...      DRAGON
# 20                                                 None        None
# 21                                                 None      DRAGON
# 22                                                 None        None
# 23    So you say you want an evolution. Well, you kn...        None
# 24                                                 None        None
# 25    It's adorable! AND OH MY GOODNESS WHY IS IT EA...  MECHANICAL
# 26    Kazakus has a squad of imps bottling Felfire r...        None
# 27                                                 None        None
# 28               No Job is too big.  No fee is too big.        None
# 29    She can tell you all about the history of peop...        None
# ...                                                 ...         ...
# 2789                                               None        None
# 2790  Lance Carrier is an obscure entry level positi...        None
# 2791                                               None        None
# 2792                                               None        None
# 2793                                               None        None
# 2794  Antonidas was the Grand Magus of the Kirin Tor...        None
# 2795                     Often followed by Holy Smokes!        None
# 2796                                               None       BEAST
# 2797     Is this a noun or a verb?  We will never know.        None
# 2798                                               None        None
# 2799                                               None        None
# 2800                                               None        None
# 2801                                               None        None
# 2802                                               None        None
# 2803                                               None        None
# 2804                                               None        None
# 2805  There is no beast more frightening (or ridicul...       BEAST
# 2806                                               None        None
# 2807                                               None        None
# 2808                                               None        None
# 2809                                               None        None
# 2810                                               None        None
# 2811                                               None        None
# 2812                                               None        None
# 2813                                               None        None
# 2814                                               None        None
# 2815  The trick is not to break the lance.  Otherwis...        None
# 2816                                               None        None
# 2817                                               None        None
# 2818                                               None        None
#
#                                             how_to_earn  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19    Unlocked in Blackrock Spire, in the Blackrock ...
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29     Unlocked in the Spire, in One Night in Karazhan.
# ...                                                 ...
# 2789                                               None
# 2790                                               None
# 2791                                               None
# 2792                                               None
# 2793                                               None
# 2794                                               None
# 2795                                               None
# 2796                                               None
# 2797                                               None
# 2798                                               None
# 2799                                               None
# 2800                                               None
# 2801                                               None
# 2802                                               None
# 2803                                               None
# 2804                                               None
# 2805                                               None
# 2806                                               None
# 2807                                               None
# 2808                                               None
# 2809                                               None
# 2810                                               None
# 2811                                               None
# 2812                                               None
# 2813                                               None
# 2814                                               None
# 2815                                               None
# 2816                                               None
# 2817                                               None
# 2818                                               None
#
#                                      how_to_earn_golden targeting_arrow_text  \
# 0                                                  None                 None
# 1                                                  None                 None
# 2                                                  None                 None
# 3                                                  None                 None
# 4                                                  None                 None
# 5                                                  None                 None
# 6                                                  None                 None
# 7                                                  None                 None
# 8                                                  None                 None
# 9                                                  None                 None
# 10                                                 None                 None
# 11                                                 None                 None
# 12                                                 None                 None
# 13                                                 None                 None
# 14                                                 None                 None
# 15                                                 None                 None
# 16                                                 None                 None
# 17                                                 None                 None
# 18                                                 None                 None
# 19    Crafting unlocked in Blackrock Spire, in the B...                 None
# 20                                                 None                 None
# 21                                                 None                 None
# 22                                                 None                 None
# 23                                                 None                 None
# 24                                                 None                 None
# 25                                                 None                 None
# 26                                                 None                 None
# 27                                                 None                 None
# 28                                                 None                 None
# 29    Crafting unlocked in the Spire, in One Night i...                 None
# ...                                                 ...                  ...
# 2789                                               None                 None
# 2790                                               None      Give +2 Attack.
# 2791                                               None                 None
# 2792                                               None                 None
# 2793                                               None                 None
# 2794                                               None                 None
# 2795                                               None                 None
# 2796                                               None                 None
# 2797                                               None                 None
# 2798                                               None                 None
# 2799                                               None                 None
# 2800                                               None                 None
# 2801                                               None                 None
# 2802                                               None                 None
# 2803                                               None                 None
# 2804                                               None                 None
# 2805                                               None                 None
# 2806                                               None                 None
# 2807                                               None                 None
# 2808                                               None                 None
# 2809                                               None                 None
# 2810                                               None                 None
# 2811                                               None                 None
# 2812                                               None                 None
# 2813                                               None                 None
# 2814                                               None                 None
# 2815                                               None                 None
# 2816                                               None                 None
# 2817                                               None                 None
# 2818                                               None                 None
#
#      faction  durability   card_id_entourages       entourage_card_id
# 0       None         NaN           KAR_A10_22              KAR_A10_09
# 1       None         NaN           KAR_A10_22              KAR_A10_02
# 2       None         NaN           KAR_A10_22              KAR_A10_08
# 3       None         NaN           KAR_A10_22              KAR_A10_04
# 4       None         NaN           KAR_A10_22              KAR_A10_05
# 5       None         NaN             TBST_006                TBST_003
# 6       None         NaN             TBST_006                TBST_002
# 7       None         NaN             TBST_006                TBST_001
# 8       None         NaN           BRMA14_10H                BRMA14_3
# 9       None         NaN           BRMA14_10H               BRMA14_5H
# 10      None         NaN           BRMA14_10H               BRMA14_7H
# 11      None         NaN           BRMA14_10H               BRMA14_9H
# 12      None         NaN             BRMA09_3                BRMA09_2
# 13      None         NaN             BRMA09_3                BRMA09_4
# 14      None         NaN             BRMA09_3                BRMA09_5
# 15      None         NaN         KARA_06_03hp              KARA_06_01
# 16      None         NaN             BRMA12_2                BRMA12_6
# 17      None         NaN             BRMA12_2                BRMA12_5
# 18      None         NaN             BRMA12_2                BRMA12_7
# 19      None         NaN             BRMA12_2                BRMA12_4
# 20      None         NaN             BRMA12_2                BRMA12_3
# 21      None         NaN  TB_PickYourFate_2nd       TB_PickYourFate_1
# 22      None         NaN  TB_PickYourFate_2nd       TB_PickYourFate_4
# 23      None         NaN  TB_PickYourFate_2nd   TB_PickYourFate_7_2nd
# 24      None         NaN  TB_PickYourFate_2nd       TB_PickYourFate_3
# 25      None         NaN  TB_PickYourFate_2nd   TB_PickYourFate_6_2nd
# 26      None         NaN  TB_PickYourFate_2nd  TB_PickYourFate_11rand
# 27      None         NaN               TB_001               BRMA14_10
# 28     HORDE         NaN               TB_001              BRMA14_10H
# 29      None         NaN               TB_001                BRMA09_4
# ...      ...         ...                  ...                     ...
# 2789    None         NaN                  NaN                     NaN
# 2790    None         NaN                  NaN                     NaN
# 2791    None         NaN                  NaN                     NaN
# 2792    None         NaN                  NaN                     NaN
# 2793    None         NaN                  NaN                     NaN
# 2794    None         NaN                  NaN                     NaN
# 2795    None         NaN                  NaN                     NaN
# 2796    None         NaN                  NaN                     NaN
# 2797    None         NaN                  NaN                     NaN
# 2798    None         NaN                  NaN                     NaN
# 2799    None         NaN                  NaN                     NaN
# 2800    None         NaN                  NaN                     NaN
# 2801    None         NaN                  NaN                     NaN
# 2802    None         NaN                  NaN                     NaN
# 2803    None         NaN                  NaN                     NaN
# 2804    None         NaN                  NaN                     NaN
# 2805    None         NaN                  NaN                     NaN
# 2806    None         NaN                  NaN                     NaN
# 2807    None         NaN                  NaN                     NaN
# 2808    None         NaN                  NaN                     NaN
# 2809    None         NaN                  NaN                     NaN
# 2810    None         NaN                  NaN                     NaN
# 2811    None         NaN                  NaN                     NaN
# 2812    None         NaN                  NaN                     NaN
# 2813    None         NaN                  NaN                     NaN
# 2814    None         NaN                  NaN                     NaN
# 2815    None         NaN                  NaN                     NaN
# 2816    None         NaN                  NaN                     NaN
# 2817    None         NaN                  NaN                     NaN
# 2818    None         NaN                  NaN                     NaN
#
# [2819 rows x 20 columns]

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, we learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Use `sqlalchemy` to connect to a sqlite database and read in individual tables as DataFrames
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
